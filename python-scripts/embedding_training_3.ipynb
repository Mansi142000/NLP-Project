# %%
import pandas as pd
import ast

# %%
def parse_column(value):
    try:
        return ast.literal_eval(value) if isinstance(value, str) and value.startswith("[") else value
    except (ValueError, SyntaxError):
        return value

# %%
# Load the CSV back into a dictionary
df_loaded = pd.read_csv("./../cleaned_database/cleaned_final_dataset.csv", converters={
    "writers": parse_column,
    "directors": parse_column,
    "stars": parse_column,
    "countries_origin": parse_column,
    "filming_locations": parse_column,
    "production_companies": parse_column,
    "awards_content": parse_column,
    "genres": parse_column,
    "languages": parse_column
})

# %%
movie_data_dict= df_loaded.set_index("id").to_dict(orient="index")

# %%
first_5_keys = list(movie_data_dict.keys())[:5]
for key in first_5_keys:
    print(f"Movie ID: {key}, Data: {movie_data_dict[key]}")
# Out:
# Movie ID: tt0073195, Data: {'title': 'Jaws', 'year': 1975, 'duration': 124, 'MPA': 'PG', 'rating': 8.1, 'votes': '690K', 'meta_score': 87.0, 'description': "When a massive killer shark unleashes chaos on a beach community off Long Island, it's up to a local sheriff, a marine biologist, and an old seafarer to hunt the beast down.", 'Movie_Link': 'https://www.imdb.com/title/tt0073195', 'writers': ['Peter Benchley', 'Carl Gottlieb'], 'directors': ['Steven Spielberg'], 'stars': ['Roy Scheider', 'Robert Shaw', 'Richard Dreyfuss', 'Lorraine Gary', 'Murray Hamilton', 'Carl Gottlieb', 'Jeffrey Kramer', 'Susan Backlinie', 'Jonathan Filley', 'Ted Grossman'], 'budget': '$7,000,000 (estimated)', 'opening_weekend_gross': '$7,061,513', 'gross_worldwide': '$477,916,625', 'gross_us_canada': '$267,263,625', 'release_date': 1975.0, 'countries_origin': ['United States'], 'filming_locations': ["Water Street, Edgartown, Martha's Vineyard, Massachusetts, USA"], 'production_companies': ['Zanuck/Brown Productions', 'Universal Pictures'], 'awards_content': ['Won 3 Oscars', '16 wins & 20 nominations total'], 'genres': ['Monster Horror', 'Sea Adventure', 'Survival', 'Adventure', 'Drama', 'Horror', 'Thriller'], 'languages': ['English']}
# Movie ID: tt0073629, Data: {'title': 'The Rocky Horror Picture Show', 'year': 1975, 'duration': 100, 'MPA': 'R', 'rating': 7.4, 'votes': '174K', 'meta_score': 65.0, 'description': 'A newly-engaged couple have a breakdown in an isolated area and must seek shelter at the bizarre residence of Dr. Frank-n-Furter.', 'Movie_Link': 'https://www.imdb.com/title/tt0073629', 'writers': ["Richard O'Brien", 'Jim Sharman'], 'directors': ['Jim Sharman'], 'stars': ['Tim Curry', 'Susan Sarandon', 'Barry Bostwick', "Richard O'Brien", 'Patricia Quinn', 'Nell Campbell', 'Jonathan Adams', 'Peter Hinwood', 'Meat Loaf', 'Charles Gray'], 'budget': '$1,200,000 (estimated)', 'opening_weekend_gross': nan, 'gross_worldwide': '$115,827,018', 'gross_us_canada': '$112,892,319', 'release_date': 1975.0, 'countries_origin': ['United Kingdom', 'United States'], 'filming_locations': ["Oakley Court, Windsor Road, Oakley Green, Windsor, Berkshire, England, UK (castle exterior, criminologist's study, Brad's room, Janet's room, dining room, Columbia's room, entrance hall and stairs)"], 'production_companies': ['Twentieth Century Fox', 'Michael White Productions'], 'awards_content': ['Awards', '3 wins & 4 nominations total'], 'genres': ['B-Horror', 'Dark Comedy', 'Parody', 'Raunchy Comedy', 'Rock Musical', 'Supernatural Horror', 'Comedy', 'Horror', 'Musical'], 'languages': ['English']}
# Movie ID: tt0073486, Data: {'title': "One Flew Over the Cuckoo's Nest", 'year': 1975, 'duration': 133, 'MPA': 'R', 'rating': 8.7, 'votes': '1.1M', 'meta_score': 84.0, 'description': 'In the Fall of 1963, a Korean War veteran and criminal pleads insanity and is admitted to a mental institution, where he rallies up the scared patients against the tyrannical nurse.', 'Movie_Link': 'https://www.imdb.com/title/tt0073486', 'writers': ['Lawrence Hauben', 'Bo Goldman', 'Ken Kesey'], 'directors': ['Milos Forman'], 'stars': ['Jack Nicholson', 'Louise Fletcher', 'Michael Berryman', 'Peter Brocco', 'Dean R. Brooks', 'Alonzo Brown', 'Scatman Crothers', 'Mwako Cumbuka', 'Danny DeVito', 'William Duell'], 'budget': '$3,000,000 (estimated)', 'opening_weekend_gross': nan, 'gross_worldwide': '$109,115,366', 'gross_us_canada': '$108,981,275', 'release_date': 1975.0, 'countries_origin': ['United States'], 'filming_locations': ['Oregon State Mental Hospital - 2600 Center Street NE, Salem, Oregon, USA'], 'production_companies': ['Fantasy Films', 'N.V. Zvaluw'], 'awards_content': ['Won 5 Oscars', '38 wins & 15 nominations total'], 'genres': ['Medical Drama', 'Psychological Drama', 'Drama'], 'languages': ['English']}
# Movie ID: tt0072890, Data: {'title': 'Dog Day Afternoon', 'year': 1975, 'duration': 125, 'MPA': 'R', 'rating': 8.0, 'votes': '281K', 'meta_score': 86.0, 'description': 'Three amateur robbers plan to hold up a Brooklyn bank. A nice, simple robbery: Walk in, take the money, and run. Unfortunately, the supposedly uncomplicated heist suddenly becomes a bizarre nightmare as everything that could go wrong does.', 'Movie_Link': 'https://www.imdb.com/title/tt0072890', 'writers': ['Frank Pierson', 'P.F. Kluge', 'Thomas Moore'], 'directors': ['Sidney Lumet'], 'stars': ['Al Pacino', 'John Cazale', 'Penelope Allen', 'Sully Boyar', 'Beulah Garrick', 'Carol Kane', 'Sandra Kazan', 'Marcia Jean Kurtz', 'Amy Levitt', 'John Marriott'], 'budget': '$1,800,000 (estimated)', 'opening_weekend_gross': nan, 'gross_worldwide': '$50,004,527', 'gross_us_canada': '$50,000,000', 'release_date': 1975.0, 'countries_origin': ['United States'], 'filming_locations': ['285 Prospect Park West, Brooklyn, New York City, New York, USA (Bank exterior)'], 'production_companies': ['Warner Bros.', 'Artists Entertainment Complex'], 'awards_content': ['Won 1 Oscar', '14 wins & 20 nominations total'], 'genres': ['Dark Comedy', 'Heist', 'True Crime', 'Biography', 'Crime', 'Drama', 'Thriller'], 'languages': ['English']}
# Movie ID: tt0073692, Data: {'title': 'Shampoo', 'year': 1975, 'duration': 110, 'MPA': 'R', 'rating': 6.4, 'votes': '15K', 'meta_score': 65.0, 'description': "On Election Day, 1968, irresponsible hairdresser and ladies' man George Roundy is too busy cutting hair and dealing with his girlfriends and mistress Felicia Karpf, whose husband Lester is having an affair with his ex-girlfriend Jackie.", 'Movie_Link': 'https://www.imdb.com/title/tt0073692', 'writers': ['Robert Towne', 'Warren Beatty'], 'directors': ['Hal Ashby'], 'stars': ['Warren Beatty', 'Julie Christie', 'Goldie Hawn', 'Lee Grant', 'Jack Warden', 'Tony Bill', 'George Furth', 'Jay Robinson', 'Ann Weldon', 'Luana Anders'], 'budget': '$4,000,000 (estimated)', 'opening_weekend_gross': nan, 'gross_worldwide': '$49,407,734', 'gross_us_canada': '$49,407,734', 'release_date': 1975.0, 'countries_origin': ['United States'], 'filming_locations': ["2270 Bowmont Drive, Beverly Hills, California, USA (Jackie's House at Bowmont & Hazen)"], 'production_companies': ['Persky-Bright / Vista', 'Columbia Pictures', 'Rubeeker Films'], 'awards_content': ['Won 1 Oscar', '3 wins & 11 nominations total'], 'genres': ['Satire', 'Comedy', 'Drama'], 'languages': ['English']}

# %%
pip install chromadb
# Out:
# Requirement already satisfied: chromadb in c:\users\rohandalvi\anaconda3\lib\site-packages (0.6.3)
# Requirement already satisfied: build>=1.0.3 in c:\users\rohandalvi\anaconda3\lib\site-packages (from chromadb) (1.2.2.post1)
# Requirement already satisfied: pydantic>=1.9 in c:\users\rohandalvi\anaconda3\lib\site-packages (from chromadb) (2.8.2)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in c:\users\rohandalvi\anaconda3\lib\site-packages (from chromadb) (0.7.6)
# Requirement already satisfied: fastapi>=0.95.2 in c:\users\rohandalvi\anaconda3\lib\site-packages (from chromadb) (0.115.11)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\rohandalvi\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.34.0)
# Requirement already satisfied: numpy>=1.22.5 in c:\users\rohandalvi\anaconda3\lib\site-packages (from chromadb) (1.26.4)
# Requirement already satisfied: posthog>=2.4.0 in c:\users\rohandalvi\anaconda3\lib\site-packages (from chromadb) (3.21.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\rohandalvi\anaconda3\lib\site-packages (from chromadb) (4.11.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\rohandalvi\anaconda3\lib\site-packages (from chromadb) (1.21.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\rohandalvi\anaconda3\lib\site-packages (from chromadb) (1.31.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\rohandalvi\anaconda3\lib\site-packages (from chromadb) (1.31.1)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in c:\users\rohandalvi\anaconda3\lib\site-packages (from chromadb) (0.52b1)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\rohandalvi\anaconda3\lib\site-packages (from chromadb) (1.31.1)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\rohandalvi\anaconda3\lib\site-packages (from chromadb) (0.21.1)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\rohandalvi\anaconda3\lib\site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\rohandalvi\anaconda3\lib\site-packages (from chromadb) (4.66.5)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\rohandalvi\anaconda3\lib\site-packages (from chromadb) (7.4.0)
# Requirement already satisfied: importlib-resources in c:\users\rohandalvi\anaconda3\lib\site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\rohandalvi\anaconda3\lib\site-packages (from chromadb) (1.71.0)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\rohandalvi\anaconda3\lib\site-packages (from chromadb) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\rohandalvi\anaconda3\lib\site-packages (from chromadb) (0.9.0)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\rohandalvi\anaconda3\lib\site-packages (from chromadb) (32.0.1)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\rohandalvi\anaconda3\lib\site-packages (from chromadb) (8.2.3)
# Requirement already satisfied: PyYAML>=6.0.0 in c:\users\rohandalvi\anaconda3\lib\site-packages (from chromadb) (6.0.1)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\rohandalvi\anaconda3\lib\site-packages (from chromadb) (5.1.0)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\rohandalvi\anaconda3\lib\site-packages (from chromadb) (3.10.15)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\rohandalvi\anaconda3\lib\site-packages (from chromadb) (0.27.0)
# Requirement already satisfied: rich>=10.11.0 in c:\users\rohandalvi\anaconda3\lib\site-packages (from chromadb) (13.7.1)
# Requirement already satisfied: packaging>=19.1 in c:\users\rohandalvi\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (24.1)
# Requirement already satisfied: pyproject_hooks in c:\users\rohandalvi\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in c:\users\rohandalvi\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in c:\users\rohandalvi\anaconda3\lib\site-packages (from fastapi>=0.95.2->chromadb) (0.46.1)
# Requirement already satisfied: anyio in c:\users\rohandalvi\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (4.2.0)
# Requirement already satisfied: certifi in c:\users\rohandalvi\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in c:\users\rohandalvi\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (1.0.2)
# Requirement already satisfied: idna in c:\users\rohandalvi\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (3.7)
# Requirement already satisfied: sniffio in c:\users\rohandalvi\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\rohandalvi\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.14.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\rohandalvi\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\rohandalvi\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\rohandalvi\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.38.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\rohandalvi\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests in c:\users\rohandalvi\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.32.3)
# Requirement already satisfied: requests-oauthlib in c:\users\rohandalvi\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\rohandalvi\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in c:\users\rohandalvi\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.2.3)
# Requirement already satisfied: durationpy>=0.7 in c:\users\rohandalvi\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.9)
# Requirement already satisfied: coloredlogs in c:\users\rohandalvi\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\rohandalvi\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (25.2.10)
# Requirement already satisfied: protobuf in c:\users\rohandalvi\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (5.29.4)
# Requirement already satisfied: sympy in c:\users\rohandalvi\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.13.1)
# Requirement already satisfied: deprecated>=1.2.6 in c:\users\rohandalvi\anaconda3\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (1.2.18)
# Requirement already satisfied: importlib-metadata<8.7.0,>=6.0 in c:\users\rohandalvi\anaconda3\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (7.0.1)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\rohandalvi\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.69.2)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.31.1 in c:\users\rohandalvi\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.31.1)
# Requirement already satisfied: opentelemetry-proto==1.31.1 in c:\users\rohandalvi\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.31.1)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.52b1 in c:\users\rohandalvi\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.52b1)
# Requirement already satisfied: opentelemetry-instrumentation==0.52b1 in c:\users\rohandalvi\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.52b1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.52b1 in c:\users\rohandalvi\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.52b1)
# Requirement already satisfied: opentelemetry-util-http==0.52b1 in c:\users\rohandalvi\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.52b1)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in c:\users\rohandalvi\anaconda3\lib\site-packages (from opentelemetry-instrumentation==0.52b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.14.1)
# Requirement already satisfied: asgiref~=3.0 in c:\users\rohandalvi\anaconda3\lib\site-packages (from opentelemetry-instrumentation-asgi==0.52b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in c:\users\rohandalvi\anaconda3\lib\site-packages (from posthog>=2.4.0->chromadb) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\rohandalvi\anaconda3\lib\site-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in c:\users\rohandalvi\anaconda3\lib\site-packages (from posthog>=2.4.0->chromadb) (1.9.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\rohandalvi\anaconda3\lib\site-packages (from pydantic>=1.9->chromadb) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\rohandalvi\anaconda3\lib\site-packages (from pydantic>=1.9->chromadb) (2.20.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\rohandalvi\anaconda3\lib\site-packages (from rich>=10.11.0->chromadb) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\rohandalvi\anaconda3\lib\site-packages (from rich>=10.11.0->chromadb) (2.15.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\rohandalvi\anaconda3\lib\site-packages (from tokenizers>=0.13.2->chromadb) (0.29.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\rohandalvi\anaconda3\lib\site-packages (from typer>=0.9.0->chromadb) (8.1.7)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\rohandalvi\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.4)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\rohandalvi\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\rohandalvi\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.4)
# Requirement already satisfied: websockets>=10.4 in c:\users\rohandalvi\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\rohandalvi\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\rohandalvi\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\rohandalvi\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9)
# Requirement already satisfied: filelock in c:\users\rohandalvi\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\rohandalvi\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2024.6.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\rohandalvi\anaconda3\lib\site-packages (from importlib-metadata<8.7.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.17.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\rohandalvi\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\rohandalvi\anaconda3\lib\site-packages (from requests->kubernetes>=28.1.0->chromadb) (3.3.2)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\rohandalvi\anaconda3\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\rohandalvi\anaconda3\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: pyreadline3 in c:\users\rohandalvi\anaconda3\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb) (3.5.4)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\rohandalvi\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.8)
# Note: you may need to restart the kernel to use updated packages.

# %%
import chromadb

# %%
chroma_client = chromadb.PersistentClient(path="./../chromadb_client")

# %%
collection = chroma_client.create_collection(name="best_movies_database")

# %%
chroma_client.delete_collection(name="best_movies_database")

# %%
def insert_movies_to_chroma(movie_data_dict, batch_size=30000):
    separator = " , "
    movie_items = list(movie_data_dict.items())  
    total_movies = len(movie_items)

    for i in range(0, total_movies, batch_size):
        batch = movie_items[i:i + batch_size]  

        documents = []
        metadatas = []
        ids = []

        for movie_id, movie_data in batch:
            joint_stars_string = separator.join(movie_data.get("stars", []))
            joint_genres_string = separator.join(movie_data.get("genres", []))
            joint_productions_string = separator.join(movie_data.get("production_companies", []))
            joint_filming_locations_string = separator.join(movie_data.get("filming_locations", []))
            joint_countries_origin_string = separator.join(movie_data.get("countries_origin", []))
            joint_directors_string = separator.join(movie_data.get("directors", []))
            joint_languages_string = separator.join(movie_data.get("languages", []))

            document = f"{movie_data['title']} | {movie_data['description']} | {joint_stars_string} | {joint_genres_string} | {joint_productions_string} | {joint_filming_locations_string} | {joint_countries_origin_string} | {joint_directors_string} | {joint_languages_string}"
            metadata = {
                "title": movie_data.get("title"),
                "year": movie_data.get("year"),
                "duration": movie_data.get("duration"),
                "MPA": movie_data.get("MPA"),
                "rating": movie_data.get("rating"),
                "votes": movie_data.get("votes"),
                "meta_score": movie_data.get("meta_score"),
                "description": movie_data.get("description"),
                "Movie_Link": movie_data.get("Movie_Link"),
                "writers": separator.join(movie_data.get("writers", [])),
                "directors": joint_directors_string,
                "stars": joint_stars_string,
                "budget": movie_data.get("budget"),
                "opening_weekend_gross": movie_data.get("opening_weekend_gross"),
                "gross_worldwide": movie_data.get("gross_worldwide"),
                "gross_us_canada": movie_data.get("gross_us_canada"),
                "release_date": movie_data.get("release_date"),
                "countries_origin": joint_countries_origin_string,
                "filming_locations": joint_filming_locations_string,
                "production_companies": joint_productions_string,
                "awards_content": separator.join(movie_data.get("awards_content", [])),
                "genres": joint_genres_string,
                "languages": joint_languages_string
            }
            documents.append(document)
            metadatas.append(metadata)
            ids.append(str(movie_id))

        collection.add(documents=documents, metadatas=metadatas, ids=ids)

        print(f"Inserted batch {i // batch_size + 1} ({len(batch)} movies) into Chroma.")

    print(f"Completed: Inserted {total_movies} movies into Chroma in batches of {batch_size}.")

# %%
print(movie_data_dict['tt0073486'])
# Out:
# {'title': "One Flew Over the Cuckoo's Nest", 'year': 1975, 'duration': 133, 'MPA': 'R', 'rating': 8.7, 'votes': '1.1M', 'meta_score': 84.0, 'description': 'In the Fall of 1963, a Korean War veteran and criminal pleads insanity and is admitted to a mental institution, where he rallies up the scared patients against the tyrannical nurse.', 'Movie_Link': 'https://www.imdb.com/title/tt0073486', 'writers': ['Lawrence Hauben', 'Bo Goldman', 'Ken Kesey'], 'directors': ['Milos Forman'], 'stars': ['Jack Nicholson', 'Louise Fletcher', 'Michael Berryman', 'Peter Brocco', 'Dean R. Brooks', 'Alonzo Brown', 'Scatman Crothers', 'Mwako Cumbuka', 'Danny DeVito', 'William Duell'], 'budget': '$3,000,000 (estimated)', 'opening_weekend_gross': nan, 'gross_worldwide': '$109,115,366', 'gross_us_canada': '$108,981,275', 'release_date': 1975.0, 'countries_origin': ['United States'], 'filming_locations': ['Oregon State Mental Hospital - 2600 Center Street NE, Salem, Oregon, USA'], 'production_companies': ['Fantasy Films', 'N.V. Zvaluw'], 'awards_content': ['Won 5 Oscars', '38 wins & 15 nominations total'], 'genres': ['Medical Drama', 'Psychological Drama', 'Drama'], 'languages': ['English']}

# %%
insert_movies_to_chroma(movie_data_dict,10000)
# Out:
# Inserted batch 1 (10000 movies) into Chroma.
# Inserted batch 2 (10000 movies) into Chroma.
# Inserted batch 3 (10000 movies) into Chroma.
# Inserted batch 4 (10000 movies) into Chroma.
# Inserted batch 5 (10000 movies) into Chroma.
# Inserted batch 6 (10000 movies) into Chroma.
# Inserted batch 7 (3249 movies) into Chroma.
# Completed: Inserted 63249 movies into Chroma in batches of 10000.

# %%
# Assuming movie_data_dict is your dictionary
def insert_first_1000(movie_data_dict):
    """Inserts the first 1000 items from the dictionary."""

    first_1000 = {}
    keys = list(movie_data_dict.keys())

    for i in range(min(1000, len(keys))): #prevent error if the dictionary has less than 1000 items
        print(keys[i])
        first_1000[keys[i]] = movie_data_dict[keys[i]]
        
    insert_movies_to_chroma(first_1000)

# %%
insert_first_1000(movie_data_dict)
# Out:
# tt0073195
# tt0073629
# tt0073486
# tt0072890
# tt0073692
# tt0072081
# tt0073026
# tt0072653
# tt0073812
# tt0073802
# tt0073317
# tt0073075
# tt0073312
# tt0072951
# tt0073190
# tt0072926
# tt0073018
# tt0074539
# tt0073053
# tt0073440
# tt0072750
# tt0071853
# tt0073015
# tt0072665
# tt0073580
# tt0073043
# tt0073540
# tt0073778
# tt0073076
# tt0072443
# tt0073155
# tt0075040
# tt0072976
# tt0073424
# tt0073114
# tt0073650
# tt0072684
# tt0073768
# tt0073453
# tt0073631
# tt0072856
# tt0073198
# tt0073747
# tt0071650
# tt0073341
# tt0073705
# tt0072752
# tt0073582
# tt0073349
# tt0073636
# tt0072705
# tt0072730
# tt0316900
# tt0073115
# tt0072735
# tt0073092
# tt0073559
# tt0073172
# tt0073470
# tt0073594
# tt0072973
# tt0073597
# tt0074682
# tt0072930
# tt0073906
# tt0073501
# tt0073240
# tt0072912
# tt0072732
# tt0073019
# tt0069930
# tt0073600
# tt0073707
# tt0071411
# tt0073298
# tt0073496
# tt0073691
# tt0072820
# tt0072848
# tt0072709
# tt0072869
# tt0131526
# tt0073637
# tt0075140
# tt0073722
# tt0073203
# tt0073870
# tt0073324
# tt0073605
# tt0073000
# tt0072761
# tt0072798
# tt0072764
# tt0072184
# tt0073615
# tt0252487
# tt0072895
# tt0074800
# tt0072933
# tt0073282
# tt0073036
# tt0087132
# tt0073335
# tt0075432
# tt0072610
# tt0072448
# tt0072737
# tt0073373
# tt0073822
# tt0073766
# tt0072608
# tt0073760
# tt0073170
# tt0073896
# tt0073343
# tt0073113
# tt0073133
# tt0073109
# tt0073836
# tt0073764
# tt0256308
# tt0073864
# tt0072814
# tt0073107
# tt0071483
# tt0073233
# tt0073697
# tt0073773
# tt0072961
# tt0072747
# tt0073878
# tt0073398
# tt0080479
# tt0073008
# tt0073091
# tt0071537
# tt0075016
# tt0072953
# tt0123949
# tt0074472
# tt0073363
# tt0073526
# tt0072886
# tt0073624
# tt0075019
# tt0072812
# tt0073535
# tt0072829
# tt0073461
# tt0073634
# tt0071950
# tt0072034
# tt0073835
# tt0072894
# tt0073345
# tt0072637
# tt0073800
# tt0073620
# tt0073387
# tt0073290
# tt0073858
# tt0223777
# tt0071231
# tt0073270
# tt0073901
# tt0072905
# tt0073396
# tt0072867
# tt0073639
# tt0073688
# tt0073941
# tt0073006
# tt0072662
# tt0071344
# tt0186797
# tt0070312
# tt0073169
# tt0069735
# tt0070636
# tt0073286
# tt0071486
# tt0071093
# tt9270362
# tt0073655
# tt0068734
# tt0073586
# tt0072822
# tt0361505
# tt0128451
# tt0072819
# tt0126019
# tt0073847
# tt0073042
# tt0187192
# tt0074423
# tt0074873
# tt0073784
# tt0071398
# tt6037370
# tt0072594
# tt0073096
# tt0287617
# tt0076038
# tt0072695
# tt0073871
# tt0073028
# tt0073327
# tt0201070
# tt0082955
# tt0073051
# tt0073946
# tt0239096
# tt0073502
# tt0071854
# tt0073880
# tt0187044
# tt0072860
# tt3088364
# tt0073797
# tt0073485
# tt0071897
# tt3420392
# tt0079058
# tt0071557
# tt0257099
# tt0173866
# tt0075097
# tt0072771
# tt0083155
# tt0192472
# tt0144246
# tt0072053
# tt0072826
# tt0073202
# tt0072605
# tt0073218
# tt0072831
# tt0072446
# tt0071131
# tt0211255
# tt0070834
# tt0073168
# tt0071967
# tt0072623
# tt0254688
# tt0068204
# tt0213652
# tt0072615
# tt0381985
# tt0072996
# tt0071341
# tt0146872
# tt0073488
# tt0073698
# tt0071384
# tt0073668
# tt0072791
# tt0072714
# tt0072904
# tt0071512
# tt0073845
# tt0072179
# tt0073903
# tt0073524
# tt0071297
# tt0072614
# tt0072084
# tt0072770
# tt0073679
# tt0073135
# tt0178186
# tt0169620
# tt0073103
# tt0071882
# tt0071465
# tt0072706
# tt0071478
# tt0073206
# tt0073846
# tt0074381
# tt0072919
# tt0072773
# tt0187530
# tt0166748
# tt0073618
# tt0073530
# tt7620704
# tt0079349
# tt0328619
# tt0072656
# tt0073205
# tt0070326
# tt0073131
# tt0145761
# tt0073406
# tt0073703
# tt0073102
# tt0071987
# tt0073601
# tt0073163
# tt0073469
# tt0072827
# tt0206381
# tt0072342
# tt0074849
# tt0071756
# tt0207983
# tt0072932
# tt0260440
# tt0073554
# tt0071204
# tt7837422
# tt0072786
# tt0252488
# tt0073181
# tt0073739
# tt0073067
# tt0155306
# tt0073045
# tt0072833
# tt0070031
# tt0073765
# tt0073328
# tt0072966
# tt0073511
# tt0070556
# tt0073775
# tt0256116
# tt0073208
# tt0073541
# tt0071834
# tt0073224
# tt0071885
# tt0072759
# tt0165239
# tt0131449
# tt0071552
# tt0073338
# tt0195537
# tt0073861
# tt0073029
# tt0071798
# tt0072668
# tt0071765
# tt0070871
# tt0072782
# tt0073915
# tt0072597
# tt0072685
# tt0071112
# tt0165795
# tt0073259
# tt0073716
# tt0072208
# tt0073411
# tt0072993
# tt0257667
# tt0072825
# tt0073471
# tt0071543
# tt0183466
# tt0072222
# tt0073326
# tt0073923
# tt0073275
# tt0073460
# tt0072634
# tt0073266
# tt0080897
# tt0072393
# tt2321247
# tt0073151
# tt0072008
# tt0263607
# tt0073279
# tt0072783
# tt0073166
# tt6649276
# tt0073590
# tt0198769
# tt0074210
# tt0073646
# tt0072844
# tt0073207
# tt0167281
# tt0124046
# tt0072603
# tt29266802
# tt0072910
# tt0073174
# tt0221269
# tt0072794
# tt0073762
# tt0073367
# tt0072613
# tt0074149
# tt0073278
# tt0073663
# tt0072699
# tt0073660
# tt0071661
# tt0151511
# tt0392318
# tt0302961
# tt0072596
# tt0072123
# tt0074657
# tt0235433
# tt0073683
# tt0168265
# tt0181966
# tt0075915
# tt0073098
# tt0072924
# tt0073695
# tt0280440
# tt0073213
# tt0072723
# tt0073841
# tt0074570
# tt0075083
# tt0073735
# tt0073815
# tt0073633
# tt0073357
# tt0499305
# tt0073391
# tt0202114
# tt1219153
# tt0071471
# tt0071957
# tt0246493
# tt0285663
# tt0216110
# tt0071389
# tt0182260
# tt1547444
# tt0154159
# tt0070940
# tt0073598
# tt0074741
# tt0073736
# tt0071558
# tt0073529
# tt0073543
# tt0072843
# tt0180784
# tt0072447
# tt0140529
# tt0084272
# tt0072205
# tt0173990
# tt0075141
# tt0215900
# tt0182967
# tt0073480
# tt0065685
# tt0073302
# tt0327539
# tt0073293
# tt0073061
# tt0280586
# tt0071101
# tt0072776
# tt0074710
# tt0456047
# tt0235971
# tt0126968
# tt0072877
# tt0073948
# tt0073458
# tt0252496
# tt0072618
# tt0226585
# tt0074775
# tt0073767
# tt0071449
# tt0073713
# tt0073011
# tt0073887
# tt0172195
# tt0073720
# tt0073121
# tt0075377
# tt0073924
# tt0155581
# tt0072785
# tt0073830
# tt17237206
# tt0122505
# tt0073069
# tt0071651
# tt0072640
# tt0073215
# tt0253300
# tt0073657
# tt0073442
# tt0224092
# tt0074299
# tt0308558
# tt0288140
# tt2393868
# tt0071496
# tt1018863
# tt0223453
# tt0072874
# tt0076051
# tt0246420
# tt0073035
# tt0090318
# tt0075454
# tt0072722
# tt0253848
# tt0075007
# tt0276970
# tt0297149
# tt0073427
# tt0073902
# tt0075419
# tt0232264
# tt0074975
# tt0074222
# tt0194125
# tt0291968
# tt0071265
# tt0073079
# tt0072707
# tt0072595
# tt0141446
# tt0304432
# tt0264868
# tt0071138
# tt0072604
# tt6538382
# tt5520934
# tt0074885
# tt0073191
# tt0363110
# tt0073891
# tt0170841
# tt0122988
# tt0279919
# tt0070663
# tt0073569
# tt1877747
# tt0074542
# tt0077925
# tt0073210
# tt0072590
# tt0072641
# tt0072003
# tt0228461
# tt0072944
# tt1332103
# tt1104069
# tt0262328
# tt0072742
# tt0069887
# tt0370765
# tt0072891
# tt0075203
# tt0152492
# tt0073234
# tt0222225
# tt0072972
# tt0073340
# tt0073323
# tt0072712
# tt0362137
# tt0166847
# tt0280515
# tt4313280
# tt0072294
# tt0073508
# tt1522318
# tt0073709
# tt3269022
# tt2048862
# tt0072600
# tt0165348
# tt0076237
# tt1260682
# tt0073507
# tt1519400
# tt0074714
# tt0073158
# tt0131529
# tt0153520
# tt0072644
# tt0153414
# tt0070308
# tt0169815
# tt0073490
# tt0073417
# tt0239489
# tt0072858
# tt3285576
# tt1196645
# tt0071333
# tt0072790
# tt0076759
# tt0075860
# tt0076729
# tt0076666
# tt0076618
# tt0075784
# tt0075925
# tt0076752
# tt0076489
# tt0076538
# tt0075686
# tt0078227
# tt0076138
# tt0076141
# tt0076009
# tt0076137
# tt0076723
# tt0076070
# tt0076843
# tt0076507
# tt0076327
# tt0076245
# tt0075718
# tt0076044
# tt0076451
# tt0075765
# tt0076504
# tt0075774
# tt0076211
# tt0076591
# tt0076175
# tt0076234
# tt0076123
# tt0076052
# tt0076162
# tt0076042
# tt0075938
# tt0079672
# tt0076855
# tt0076164
# tt0075744
# tt0076706
# tt0076299
# tt0074486
# tt0076740
# tt0076637
# tt0076786
# tt0075950
# tt0076749
# tt0075322
# tt0077681
# tt0077294
# tt0075753
# tt0076929
# tt0076512
# tt0076683
# tt0075809
# tt0075648
# tt0075968
# tt0076257
# tt0076590
# tt0076363
# tt0074695
# tt0075984
# tt0075612
# tt0076095
# tt0075824
# tt0076221
# tt0075849
# tt0076716
# tt0076645
# tt0075921
# tt0076868
# tt0075987
# tt0076015
# tt0076500
# tt0075675
# tt0076578
# tt0074569
# tt0076535
# tt0076112
# tt0075875
# tt0075868
# tt0075404
# tt0075931
# tt0075924
# tt0076734
# tt0076210
# tt0078437
# tt0075909
# tt0077914
# tt0076155
# tt0075995
# tt0076271
# tt0076085
# tt0078344
# tt0076915
# tt0075807
# tt0076649
# tt0075276
# tt0075666
# tt0078089
# tt0074473
# tt0146289
# tt0076445
# tt0075893
# tt0076809
# tt0075989
# tt0075830
# tt0076347
# tt0077188
# tt0075850
# tt0075936
# tt0076636
# tt0076543
# tt0075614
# tt0075845
# tt0075679
# tt0075638
# tt0076294
# tt0076059
# tt0074548
# tt0076804
# tt0075783
# tt0074979
# tt0083017
# tt0075651
# tt0076704
# tt0078238
# tt0252889
# tt0077470
# tt0076100
# tt0075790
# tt0078398
# tt0155360
# tt0075913
# tt0241967
# tt0074683
# tt0076849
# tt0076585
# tt0076686
# tt0076172
# tt0074591
# tt0076665
# tt0227848
# tt0076845
# tt0075704
# tt0076319
# tt0076033
# tt0077381
# tt0086872
# tt0076125
# tt0076760
# tt0075378
# tt0077332
# tt0076312
# tt0075617
# tt0074611
# tt0076475
# tt0075069
# tt0075820
# tt0076788
# tt0076297
# tt0075932
# tt0076106
# tt0076630
# tt0075696
# tt0077497
# tt0074290
# tt0074226
# tt0075389
# tt0076409
# tt0074114
# tt0074510
# tt0074442
# tt0076937
# tt0075902
# tt0075939
# tt0076239
# tt0075339
# tt0075815
# tt0078231
# tt0209052
# tt0219646
# tt0076755
# tt0076853
# tt0085605
# tt0076715
# tt0076091
# tt0076696
# tt0076168
# tt0075889
# tt0263975
# tt0076028
# tt0076725
# tt0213611
# tt0897431
# tt0076208
# tt0253614
# tt0177226
# tt0076410
# tt0076342
# tt0076023
# tt0075940
# tt0246469
# tt0328886
# tt0076348
# tt0075990
# tt0075669
# tt0274470
# tt0074729
# tt0167165
# tt0076939
# tt0076191
# tt0193074
# tt0165214
# tt0078078
# tt0288898
# tt0075759
# tt0075681
# tt0076098
# tt0076933
# tt0075740
# tt0076873
# tt0076727
# tt0075764
# tt0075652
# tt0075682
# tt0076469
# tt0075888
# tt0076913
# tt0075944
# tt0076301
# tt0077222
# tt0076941
# tt0077762
# tt0076388
# tt0287489
# tt0385639
# tt0074687
# tt0226267
# tt0076068
# tt0075871
# tt0075852
# tt0070756
# tt0241848
# tt0072975
# tt0076790
# tt0076227
# tt0076111
# tt0259261
# tt0076890
# tt0076944
# tt0074153
# tt0076146
# tt0076154
# tt0076644
# tt0253997
# tt0075801
# tt0074419
# tt0076935
# tt0076280
# tt0084051
# tt0074273
# tt0078012
# tt0123934
# tt0075683
# tt0076902
# tt0140174
# tt0075059
# tt0075838
# tt0076746
# tt0286951
# tt0076398
# tt0076167
# tt0076825
# tt0149677
# tt0076792
# tt0076574
# tt0076495
# tt0153599
# tt0075230
# tt0074589
# tt0075710
# tt0076517
# tt0075754
# tt0076148
# tt0076869
# tt0075926
# tt0075796
# tt0074652
# tt0076478
# tt0076836
# tt0075961
# tt0076096
# tt0175694
# tt0257632
# tt0077848
# tt0076069
# tt0260472
# tt0076780
# tt0290330
# tt0076360
# tt0076516
# tt0076485
# tt0076598
# tt0074914
# tt0287552
# tt0075727
# tt0076401
# tt0074469
# tt0076417
# tt0076309
# tt0076119
# tt0076281
# tt0075677
# tt0076847
# tt0076912
# tt0075275
# tt0076735
# tt0076531
# tt0076064
# tt0077238
# tt0076550
# tt0077630
# tt0076744
# tt0076889
# tt0191182
# tt0076528
# tt0077599
# tt0076758
# tt0122116
# tt0076782
# tt0075060
# tt0129794
# tt0141901
# tt0077669
# tt0075680
# tt0081539
# tt0075717
# tt0140588
# tt0075079
# tt0806210
# tt0251278
# tt0076909
# tt0147530
# tt0228156
# tt0076545
# tt0076808
# tt0076877
# tt0075858
# tt0151073
# tt1543211
# tt0076672
# tt0078336
# tt0076527
# tt0076391
# tt0129148
# tt0076440
# tt0140448
# tt0076384
# tt0073566
# tt0285553
# tt0076446
# tt0076914
# tt0076820
# tt0078159
# tt0075720
# tt0204704
# tt0167948
# tt0226253
# tt0213322
# tt0165237
# tt0077403
# tt0253621
# tt0076851
# tt0074547
# tt0076099
# tt0076468
# tt0075894
# tt0075933
# tt0172919
# tt0075630
# tt0074810
# tt0071253
# tt0076337
# tt0075747
# tt0076124
# tt0077778
# tt0076341
# tt0076121
# tt0156608
# tt0252489
# tt0188083
# tt0076776
# tt0075716
# tt0076564
# tt0076801
# tt0076416
# tt0085830

# %%
def query_chroma_and_return_results(query_text, filter_criteria=None, result_size=1):
    
    try:
        if filter_criteria:
            results = collection.query(
                query_texts=[query_text],
                n_results=result_size,  # Get only the closest result
                where=filter_criteria,
            )
        else:
            results = collection.query(
                query_texts=[query_text],
                n_results=result_size,  # Get only the closest result
            )
        return results
    except Exception as e:
        print(f"An error occurred: {e}")

# %%
def print_first_result(results):
    if results["documents"] and results["documents"][0]:
        print("Closest Result:")
        print("Document:", results["documents"][0][0])
        if results["metadatas"] and results["metadatas"][0]:
            print("Metadata:", results["metadatas"][0][0]) 
        else:
            print("No metadata found.")
    else:
        print("No results found.")

# %%
print_first_result(query_chroma_and_return_results("meow"))
# Out:
# Closest Result:
# Document: The Cat's Meow | Semi-true story of the Hollywood murder that occurred at a star-studded gathering aboard William Randolph Hearst's yacht in 1924. | Kirsten Dunst , Cary Elwes , Edward Herrmann , Eddie Izzard , Joanna Lumley , Jennifer Tilly , Claudia Harrison , Victor Slezak , James Laurenson , Ronan Vibert | True Crime , Crime , Drama , Romance | Lionsgate , Dan Films , CP Medien AG | Kyparisi, Greece | United Kingdom , Germany , Canada , United States | Peter Bogdanovich | English
# Metadata: {'MPA': 'PG-13', 'Movie_Link': 'https://www.imdb.com/title/tt0266391', 'awards_content': 'Awards , 1 win & 1 nomination total', 'budget': '$7,000,000 (estimated)', 'countries_origin': 'United Kingdom , Germany , Canada , United States', 'description': "Semi-true story of the Hollywood murder that occurred at a star-studded gathering aboard William Randolph Hearst's yacht in 1924.", 'directors': 'Peter Bogdanovich', 'duration': 114, 'filming_locations': 'Kyparisi, Greece', 'genres': 'True Crime , Crime , Drama , Romance', 'gross_us_canada': '$3,209,481', 'gross_worldwide': '$3,646,994', 'languages': 'English', 'meta_score': 63.0, 'opening_weekend_gross': '$111,037', 'production_companies': 'Lionsgate , Dan Films , CP Medien AG', 'rating': 6.4, 'release_date': 2001.0, 'stars': 'Kirsten Dunst , Cary Elwes , Edward Herrmann , Eddie Izzard , Joanna Lumley , Jennifer Tilly , Claudia Harrison , Victor Slezak , James Laurenson , Ronan Vibert', 'title': "The Cat's Meow", 'votes': '9.3K', 'writers': 'Steven Peros', 'year': 2001}

# %%
print("Sample Documents:")
print(collection.peek())
# Out:
# Sample Documents:
# {'ids': ['tt0073195', 'tt0073629', 'tt0073486', 'tt0072890', 'tt0073692', 'tt0072081', 'tt0073026', 'tt0072653', 'tt0073812', 'tt0073802'], 'embeddings': array([[-0.078181  , -0.04806019, -0.01801634, ..., -0.02356488,
#         -0.01733995, -0.01388508],
#        [ 0.02058048, -0.03385413, -0.0162773 , ..., -0.02694552,
#         -0.04269272,  0.04451457],
#        [ 0.00431272, -0.05058424, -0.09625056, ...,  0.01264142,
#         -0.04026107,  0.00609061],
#        ...,
#        [-0.04223008, -0.0137757 ,  0.01082292, ...,  0.02292746,
#          0.06655598,  0.02441884],
#        [-0.01347995, -0.05440292,  0.00664415, ...,  0.05125343,
#         -0.00833141,  0.04367412],
#        [-0.00418359, -0.08803425, -0.08158376, ..., -0.09466381,
#         -0.10573022, -0.01495228]]), 'documents': ["Jaws | When a massive killer shark unleashes chaos on a beach community off Long Island, it's up to a local sheriff, a marine biologist, and an old seafarer to hunt the beast down. | Roy Scheider , Robert Shaw , Richard Dreyfuss , Lorraine Gary , Murray Hamilton , Carl Gottlieb , Jeffrey Kramer , Susan Backlinie , Jonathan Filley , Ted Grossman | Monster Horror , Sea Adventure , Survival , Adventure , Drama , Horror , Thriller | Zanuck/Brown Productions , Universal Pictures | Water Street, Edgartown, Martha's Vineyard, Massachusetts, USA | United States | Steven Spielberg | English", "The Rocky Horror Picture Show | A newly-engaged couple have a breakdown in an isolated area and must seek shelter at the bizarre residence of Dr. Frank-n-Furter. | Tim Curry , Susan Sarandon , Barry Bostwick , Richard O'Brien , Patricia Quinn , Nell Campbell , Jonathan Adams , Peter Hinwood , Meat Loaf , Charles Gray | B-Horror , Dark Comedy , Parody , Raunchy Comedy , Rock Musical , Supernatural Horror , Comedy , Horror , Musical | Twentieth Century Fox , Michael White Productions | Oakley Court, Windsor Road, Oakley Green, Windsor, Berkshire, England, UK (castle exterior, criminologist's study, Brad's room, Janet's room, dining room, Columbia's room, entrance hall and stairs) | United Kingdom , United States | Jim Sharman | English", "One Flew Over the Cuckoo's Nest | In the Fall of 1963, a Korean War veteran and criminal pleads insanity and is admitted to a mental institution, where he rallies up the scared patients against the tyrannical nurse. | Jack Nicholson , Louise Fletcher , Michael Berryman , Peter Brocco , Dean R. Brooks , Alonzo Brown , Scatman Crothers , Mwako Cumbuka , Danny DeVito , William Duell | Medical Drama , Psychological Drama , Drama | Fantasy Films , N.V. Zvaluw | Oregon State Mental Hospital - 2600 Center Street NE, Salem, Oregon, USA | United States | Milos Forman | English", 'Dog Day Afternoon | Three amateur robbers plan to hold up a Brooklyn bank. A nice, simple robbery: Walk in, take the money, and run. Unfortunately, the supposedly uncomplicated heist suddenly becomes a bizarre nightmare as everything that could go wrong does. | Al Pacino , John Cazale , Penelope Allen , Sully Boyar , Beulah Garrick , Carol Kane , Sandra Kazan , Marcia Jean Kurtz , Amy Levitt , John Marriott | Dark Comedy , Heist , True Crime , Biography , Crime , Drama , Thriller | Warner Bros. , Artists Entertainment Complex | 285 Prospect Park West, Brooklyn, New York City, New York, USA (Bank exterior) | United States | Sidney Lumet | English', "Shampoo | On Election Day, 1968, irresponsible hairdresser and ladies' man George Roundy is too busy cutting hair and dealing with his girlfriends and mistress Felicia Karpf, whose husband Lester is having an affair with his ex-girlfriend Jackie. | Warren Beatty , Julie Christie , Goldie Hawn , Lee Grant , Jack Warden , Tony Bill , George Furth , Jay Robinson , Ann Weldon , Luana Anders | Satire , Comedy , Drama | Persky-Bright / Vista , Columbia Pictures , Rubeeker Films | 2270 Bowmont Drive, Beverly Hills, California, USA (Jackie's House at Bowmont & Hazen) | United States | Hal Ashby | English", "The Return of the Pink Panther | Inspector Jacques Clouseau is put on the case when the Pink Panther diamond is stolen, with the Phantom's trademark glove the only clue. | Peter Sellers , Christopher Plummer , Catherine Schell , Herbert Lom , Peter Arne , Peter Jeffrey , Grégoire Aslan , David Lodge , Graham Stark , Eric Pohlmann | Farce , Slapstick , Comedy , Crime , Mystery | ITC Films , Jewel Productions , Pimlico Films | Palace Hotel, Gstaad, Switzerland (lobby scenes) | United Kingdom , United States | Blake Edwards | English", "Funny Lady | Story of singer Fanny Brice's stormy relationship with showman Billy Rose. | Barbra Streisand , James Caan , Omar Sharif , Roddy McDowall , Ben Vereen , Carole Wells , Larry Gates , Eugene Troobnick , Heidi O'Rourk ...

# %%
import random

# %%
def query_chroma_and_check_accuracy(query_text):
    results = query_chroma_and_return_results(query_text,None,1)
    if results['metadatas'] and results['metadatas'][0][0]:
        resultant_first_title = results['metadatas'][0][0]['title']
        print(f"Resultant first title: {resultant_first_title}, Query Title: {query_text}")
        return  resultant_first_title == query_text
    return False

# %%
def evaluate_search_accuracy(movie_data_dict, n_samples=20000):
    if len(movie_data_dict) < n_samples:
        print("Not enough data to sample from.")
        return
    
    sampled_movies = random.sample(list(movie_data_dict.items()), n_samples)
    correct_first_hits = 0

    for movie_id, data in sampled_movies:
        title = data['title']
        if query_chroma_and_check_accuracy(title):
            correct_first_hits += 1

    accuracy = correct_first_hits / n_samples
    print(f"Accuracy of search by name: {accuracy * 100:.2f}%")

# %%
# Example usage
evaluate_search_accuracy(movie_data_dict,100)
# Out:
# Resultant first title: Night of the Demons 2, Query Title: Night of the Demons 2
# Resultant first title: Chinese Box, Query Title: Chinese Box
# Resultant first title: Last Train Home, Query Title: The Last Train
# Resultant first title: For Worse, Query Title: For Worse
# Resultant first title: The Lower Depths, Query Title: The Lower Depths
# Resultant first title: Stolen Kisses, Query Title: Stolen Kisses
# Resultant first title: Dishkiyaoon, Query Title: Dishoom
# Resultant first title: Castles in Spain, Query Title: Castles in Spain
# Resultant first title: Grand Hotel, Query Title: Grand Exit
# Resultant first title: Sands of the Desert, Query Title: Desert Dust
# Resultant first title: A Boy of Flanders, Query Title: A Boy of Flanders
# Resultant first title: Buck, Query Title: Buck
# Resultant first title: Poem of the Sea, Query Title: The Sea of Grass
# Resultant first title: Nan quan bei tui zhan yan wang, Query Title: Nan quan bei tui zhan yan wang
# Resultant first title: The Gay Deceivers, Query Title: The Gay Deceiver
# Resultant first title: Angel on the Amazon, Query Title: Angel on the Amazon
# Resultant first title: The Warriors, Query Title: The First Hundred Years
# Resultant first title: Cloud Dancer, Query Title: Cloud Dancer
# Resultant first title: The Incredibles, Query Title: The Incredibles
# Resultant first title: The Third Secret, Query Title: The Third Secret
# Resultant first title: The Passion of Joan of Arc, Query Title: Joan of Arc at the Stake
# Resultant first title: The Old Dark House, Query Title: The Old Dark House
# Resultant first title: Die Flucht in die Ehe. Der große Flirt, Query Title: Die Flucht in die Ehe. Der große Flirt
# Resultant first title: The Street Avenger, Query Title: The Street Avenger
# Resultant first title: The Man from U.N.C.L.E., Query Title: The Man from U.N.C.L.E.
# Resultant first title: Robert und Bertram, Query Title: Robert und Bertram
# Resultant first title: Sapoot, Query Title: Sapoot
# Resultant first title: Descent Into Hell, Query Title: Descent Into Hell
# Resultant first title: Love in the Desert, Query Title: Love in the Desert
# Resultant first title: Batas Impian Ranjang Setan, Query Title: Hajka
# Resultant first title: When a Man Loves a Woman, Query Title: When a Man Loves a Woman
# Resultant first title: Strawberry & Chocolate, Query Title: Strawberry & Chocolate
# Resultant first title: The Dollar-a-Year Man, Query Title: The Man Who Paid
# Resultant first title: Pride of the Blue Grass, Query Title: Pride of the Blue Grass
# Resultant first title: Tin Soldier, Query Title: Tin Soldier
# Resultant first title: Live by Night, Query Title: Live by Night
# Resultant first title: In My Sleep, Query Title: In My Sleep
# Resultant first title: Mr Drake's Duck, Query Title: Mr Drake's Duck
# Resultant first title: Rebellion in Patagonia, Query Title: Rebellion in Patagonia
# Resultant first title: Fast Food Nation, Query Title: Fast Food
# Resultant first title: The King of the Kickboxers, Query Title: The King of the Kickboxers
# Resultant first title: Horror Rises from the Tomb, Query Title: Horror Rises from the Tomb
# Resultant first title: Furry Vengeance, Query Title: Furry Vengeance
# Resultant first title: Två killar och en tjej, Query Title: Två killar och en tjej
# Resultant first title: Deep Sea, Query Title: Deep in My Heart
# Resultant first title: Lady of Burlesque, Query Title: Mystery at the Burlesque
# Resultant first title: DragonHeart, Query Title: Dragon
# Resultant first title: Coming Home in the Dark, Query Title: Dark Passage
# Resultant first title: One Tough Cop, Query Title: One Tough Cop
# Resultant first title: Half Brothers, Query Title: Half Brothers
# Resultant first title: Lady of the Night, Query Title: Lady of the Night
# Resultant first title: Sound of Noise, Query Title: The Crowd Roars
# Resultant first title: Sadayam, Query Title: Sadayam
# Resultant first title: How They Make Adult Movies, Query Title: How They Make Adult Movies
# Resultant first title: Salamah, Query Title: Alarum
# Resultant first title: Goodfellas, Query Title: Goodfellas
# Resultant first title: Alvin Purple, Query Title: Alvin Purple
# Resultant first title: An Angel from Texas, Query Title: An Angel from Texas
# Resultant first title: Heera Moti, Query Title: Molokai
# Resultant first title: Chucho el Roto, Query Title: Chucho el Roto
# Resultant first title: The Virgin Suicides, Query Title: Virgin People
# Resultant first title: Death at Owell Rock, Query Title: Death at Owell Rock
# Resultant first title: Bikini Hotel, Query Title: Bikini Hotel
# Resultant first title: The Good Wife, Query Title: A Good Marriage
# Resultant first title: State buoni se potete, Query Title: State buoni se potete
# Resultant first title: Laughing Anne, Query Title: Laughing Anne
# Resultant first title: My Entire High School Sinking Into the Sea, Query Title: My Entire High School Sinking Into the Sea
# Resultant first title: Electric Shadows, Query Title: Electric Shadows
# Resultant first title: Happy Land, Query Title: Happy Land
# Resultant first title: The Oscar Nominated Short Films 2009: Live Action, Query Title: The Oscar Nominated Short Films 2009: Live Action
# Resultant first title: Toe to Toe, Query Title: Toe to Toe
# Resultant first title: Hubb lel-abad, Query Title: Hubb lel-abad
# Resultant first title: Junior, Query Title: Junior
# Resultant first title: Vesna na Zarechnoy ulitse, Query Title: Vesna na Zarechnoy ulitse
# Resultant first title: The Glass House, Query Title: The Glass House
# Resultant first title: Buscando a Mónica, Query Title: Buscando a Mónica
# Resultant first title: Arachnophobia, Query Title: Arachnophobia
# Resultant first title: Some Like It Hot, Query Title: Some Like It... Cold
# Resultant first title: Spanking the Monkey, Query Title: Spanking the Monkey
# Resultant first title: Jaws, Query Title: Jaws
# Resultant first title: Vampires in Havana, Query Title: Vampires in Havana
# Resultant first title: The Nun and the Sergeant, Query Title: The Nun and the Sergeant
# Resultant first title: To Be of Service, Query Title: Service
# Resultant first title: Er und sein Diener, Query Title: Er und sein Diener
# Resultant first title: The Kid, Query Title: The Kid
# Resultant first title: Tales of Robin Hood, Query Title: The Adventures of Robin Hood
# Resultant first title: The Carrier, Query Title: Carriers
# Resultant first title: The Lion of Flanders, Query Title: The Lion of Flanders
# Resultant first title: The Great Okinawa Yakuza War, Query Title: The Great Okinawa Yakuza War
# Resultant first title: Dead Mountaineer's Hotel, Query Title: Dead Mountaineer's Hotel
# Resultant first title: Beer League, Query Title: Beer League
# Resultant first title: Stagecoach to Fury, Query Title: Stagecoach to Fury
# Resultant first title: Simbad el Mareado, Query Title: Simbad el Mareado
# Resultant first title: The Four Just Men, Query Title: The Four Just Men
# Resultant first title: Rover Dangerfield, Query Title: Rover Dangerfield
# Resultant first title: Lise kommer til Byen, Query Title: Lise kommer til Byen
# Resultant first title: Sin You Sinners, Query Title: Sinners in Silk
# Resultant first title: Bowery Champs, Query Title: Bowery Champs
# Resultant first title: Bed Peace, Query Title: Bed Peace
# Resultant first title: Saat Pake Bandha, Query Title: Saat Hindustani
# Accuracy of search by name: 74.00%

# %%
evaluate_search_accuracy(movie_data_dict,100)
# Out:
# Resultant first title: The Heart of the Matter, Query Title: The Heart of the Matter
# Resultant first title: Persecuted, Query Title: Persecution
# Resultant first title: The Conspirator, Query Title: The Conspirator
# Resultant first title: Serpico, Query Title: Frank Serpico
# Resultant first title: The Lonely Lady, Query Title: The Lonely Woman
# Resultant first title: Last Embrace, Query Title: Broken Embraces
# Resultant first title: The Sailor from Gibraltar, Query Title: The Sailor from Gibraltar
# Resultant first title: The Conspirators, Query Title: The Conspirators
# Resultant first title: S21: The Khmer Rouge Killing Machine, Query Title: S21: The Khmer Rouge Killing Machine
# Resultant first title: V for Vendetta, Query Title: V for Vendetta
# Resultant first title: Seven Times Seven, Query Title: Seven
# Resultant first title: Insurance Investigator, Query Title: Insurance Investigator
# Resultant first title: A Haunted Turkish Bathhouse, Query Title: Ladies' Night in a Turkish Bath
# Resultant first title: Soldier, Query Title: A Soldier's Plaything
# Resultant first title: Kabei: Our Mother, Query Title: Kabei: Our Mother
# Resultant first title: 11-11-11, Query Title: 11:14
# Resultant first title: Trade Winds, Query Title: Trade Winds
# Resultant first title: Lucy's Really Lost Moments, Query Title: Lucy's Really Lost Moments
# Resultant first title: You Hurt My Feelings, Query Title: No Hard Feelings
# Resultant first title: The Black Marble, Query Title: The Black Marble
# Resultant first title: Whose Child Am I?, Query Title: Whose Child Am I?
# Resultant first title: One More Saturday Night, Query Title: Five Evenings
# Resultant first title: Where the North Begins, Query Title: Where the North Begins
# Resultant first title: El precio de la gloria, Query Title: El regreso del monstruo
# Resultant first title: Francis in the Haunted House, Query Title: Francis in the Haunted House
# Resultant first title: Fari nella nebbia, Query Title: Nell
# Resultant first title: Slash Dance, Query Title: Slash Dance
# Resultant first title: Underground Aces, Query Title: Underground Aces
# Resultant first title: After Midnight with Boston Blackie, Query Title: After Midnight with Boston Blackie
# Resultant first title: Countdown to Esmeralda Bay, Query Title: Countdown to Esmeralda Bay
# Resultant first title: The Scary of Sixty-First, Query Title: The Scary of Sixty-First
# Resultant first title: Made in Heaven, Query Title: Made in Heaven
# Resultant first title: The End of Innocence, Query Title: A Moment of Innocence
# Resultant first title: The Woman with the Knife, Query Title: The Woman with the Knife
# Resultant first title: The Butterfly Hunt, Query Title: The Butterfly Hunt
# Resultant first title: Here Come the Co-eds, Query Title: Here Come the Co-eds
# Resultant first title: The Crew, Query Title: Boat Trip
# Resultant first title: The Headless Ghost, Query Title: The Headless Ghost
# Resultant first title: No Reservations, Query Title: Without Reservations
# Resultant first title: The Chill Factor, Query Title: The Chill Factor
# Resultant first title: Prototype, Query Title: Prototype
# Resultant first title: Raped by an Angel 3: Sexual Fantasy of the Chief Executive, Query Title: Raped by an Angel 3: Sexual Fantasy of the Chief Executive
# Resultant first title: El gavilán vengador, Query Title: El gavilán vengador
# Resultant first title: Despicable Me 2, Query Title: Despicable Me
# Resultant first title: Just Tony, Query Title: Just Tony
# Resultant first title: Caveman, Query Title: Cavemen
# Resultant first title: A Shot in the Dark, Query Title: A Shot in the Dark
# Resultant first title: Honest Thief, Query Title: Honest Thief
# Resultant first title: Tamala 2010: A Punk Cat in Space, Query Title: Vettai
# Resultant first title: Balan, Query Title: Miss Bala
# Resultant first title: Dr. Crippen, Query Title: Dr. Crippen
# Resultant first title: Dark Blue Almost Black, Query Title: Dark Blue Almost Black
# Resultant first title: Big Leaguer, Query Title: The Walk-Offs
# Resultant first title: Deported, Query Title: Deported
# Resultant first title: Chinese Kamasutra, Query Title: Chinese Kamasutra
# Resultant first title: Curse of the Undead, Query Title: Curse of the Undead
# Resultant first title: The Chess Player, Query Title: The Chess Player
# Resultant first title: Rio Bravo, Query Title: Rio Bravo
# Resultant first title: Om Dar-B-Dar, Query Title: Darr
# Resultant first title: Cold Eyes of Fear, Query Title: Cold Eyes of Fear
# Resultant first title: Below the Fold, Query Title: Below the Fold
# Resultant first title: The Night the Lights Went Out in Georgia, Query Title: The Night the Lights Went Out in Georgia
# Resultant first title: Sugarcane, Query Title: Sugarcane
# Resultant first title: The Bruce, Query Title: The Bruce
# Resultant first title: Sealed Verdict, Query Title: Sealed Verdict
# Resultant first title: 50,000 B.C. (Before Clothing), Query Title: 10,000 BC
# Resultant first title: Flight Attendant: Scandal, Query Title: Flight Attendant: Scandal
# Resultant first title: Jee Aayan Nu, Query Title: Jee Aayan Nu
# Resultant first title: Lullaby of the Earth, Query Title: Broken Lullaby
# Resultant first title: The Zero Theorem, Query Title: Smashing the 0-Line
# Resultant first title: Toy Story 3, Query Title: Toy Story 4
# Resultant first title: PAW Patrol: The Mighty Movie, Query Title: PAW Patrol: The Mighty Movie
# Resultant first title: Presumed Innocent, Query Title: The Innocent
# Resultant first title: Terminator Genisys, Query Title: Terminator Genisys
# Resultant first title: Flight That Disappeared, Query Title: Secret Flight
# Resultant first title: Kispus, Query Title: Kispus
# Resultant first title: Are Parents People?, Query Title: Are Parents People?
# Resultant first title: The Cisco Kid and the Lady, Query Title: The Cisco Kid and the Lady
# Resultant first title: Gun Duel in Durango, Query Title: Gun Duel in Durango
# Resultant first title: Fue no shiratama, Query Title: Sansa shigure
# Resultant first title: Emmanuelle IV, Query Title: Emmanuelle IV
# Resultant first title: Queen for a Day, Query Title: The Queen
# Resultant first title: Thor: Love and Thunder, Query Title: Thor: Love and Thunder
# Resultant first title: Clemency, Query Title: Clemency
# Resultant first title: Kamelyali Kadin: Günahsiz Fahise, Query Title: Kamelyali Kadin: Günahsiz Fahise
# Resultant first title: Bad Samaritan, Query Title: Bad Samaritan
# Resultant first title: Garden of Death, Query Title: Garden of Death
# Resultant first title: Big Town, Query Title: Big Town Ideas
# Resultant first title: Magyar kívánsághangverseny, Query Title: Hote Hote Pyar Hogaya
# Resultant first title: Space Amoeba, Query Title: Space Amoeba
# Resultant first title: Barat, Query Title: Dada
# Resultant first title: Monika Vogelsang, Query Title: Der Vogelhändler
# Resultant first title: Kingsman: The Secret Service, Query Title: Kingsman: The Secret Service
# Resultant first title: Evita, Query Title: Evita
# Resultant first title: The Falcon's Adventure, Query Title: The Falcon's Adventure
# Resultant first title: Dublin Nightmare, Query Title: Dublin Nightmare
# Resultant first title: The Great Hotel Murder, Query Title: The Great Hotel Murder
# Resultant first title: The Battle of Love's Return, Query Title: The Battle of Love's Return
# Resultant first title: La belle de Cadix, Query Title: La belle meunière
# Resultant first title: El último cuplé, Query Title: El último cuplé
# Accuracy of search by name: 66.00%

# %%
evaluate_search_accuracy(movie_data_dict,1000)
# Out:
# Resultant first title: The Girl in the Pool, Query Title: The Pool
# Resultant first title: The Little Shepherd of Kingdom Come, Query Title: The Little Shepherd of Kingdom Come
# Resultant first title: The Cheerleaders, Query Title: But I'm a Cheerleader
# Resultant first title: Rid i natt!, Query Title: Rid i natt!
# Resultant first title: Love Is a Headache, Query Title: Love Is a Headache
# Resultant first title: The Naked Gun 2½: The Smell of Fear, Query Title: The Naked Gun
# Resultant first title: Caesar the Conqueror, Query Title: Hail, Caesar!
# Resultant first title: A Fine Mess, Query Title: A Fine Mess
# Resultant first title: The Paradine Case, Query Title: The Paradine Case
# Resultant first title: One Way Passage, Query Title: One Way Passage
# Resultant first title: Play Dirty, Query Title: Play Dirty
# Resultant first title: Barren Lives, Query Title: El barrendero
# Resultant first title: Armaguedon, Query Title: Armaguedon
# Resultant first title: Dark Tide, Query Title: Night Tide
# Resultant first title: I'm Not Scared, Query Title: I'm Not Scared
# Resultant first title: London in the Raw, Query Title: London in the Raw
# Resultant first title: Spring Break '83, Query Title: Spring Break '83
# Resultant first title: Hellraiser: Bloodline, Query Title: Hellraiser: Bloodline
# Resultant first title: The Lottery, Query Title: The Lottery
# Resultant first title: The Night Fighters, Query Title: On ira
# Resultant first title: The Last Rider, Query Title: His Last Race
# Resultant first title: The Woman I Stole, Query Title: The Woman I Stole
# Resultant first title: Desperately Seeking Susan, Query Title: Sexy Susan Knows How...
# Resultant first title: Zieh dich aus, Puppe, Query Title: Zieh dich aus, Puppe
# Resultant first title: Seize the Day, Query Title: Seize the Day
# Resultant first title: Girls Will Be Girls, Query Title: The Girls
# Resultant first title: The Brothers, Query Title: Four Brothers
# Resultant first title: All Things Must Pass, Query Title: All Things Must Pass
# Resultant first title: The Hired Killer, Query Title: The Hired Killer
# Resultant first title: The Final Season, Query Title: The Final Season
# Resultant first title: A Canção do Berço, Query Title: Man Called Rocca
# Resultant first title: Street of Sin, Query Title: Street of Sin
# Resultant first title: Margin Call, Query Title: Margin Call
# Resultant first title: 100 Days of Napoleon, Query Title: 100 Days of Napoleon
# Resultant first title: The Great John L., Query Title: The Great John L.
# Resultant first title: Stakeout, Query Title: Stakeout
# Resultant first title: Costa Azzurra, Query Title: Costa Azzurra
# Resultant first title: Shock Troop, Query Title: Shock Troop
# Resultant first title: The Incredibly Strange Creatures Who Stopped Living and Became Mixed-Up Zombies!!?, Query Title: The Incredibly Strange Creatures Who Stopped Living and Became Mixed-Up Zombies!!?
# Resultant first title: The Illegals, Query Title: The Illegals
# Resultant first title: Flodder in Amerika!, Query Title: Flannelfoot
# Resultant first title: Golden Exits, Query Title: Golden Exits
# Resultant first title: Baar Baar Dekho, Query Title: Romance
# Resultant first title: Bello onesto emigrato Australia sposerebbe compaesana illibata, Query Title: Bello onesto emigrato Australia sposerebbe compaesana illibata
# Resultant first title: The Golem: The Legend of Prague, Query Title: The Golem: The Legend of Prague
# Resultant first title: The Judge Steps Out, Query Title: The Judge Steps Out
# Resultant first title: When I'm Ready, Query Title: When I'm Ready
# Resultant first title: Triumphs of a Man Called Horse, Query Title: Triumphs of a Man Called Horse
# Resultant first title: Hell Is a City, Query Title: Hell Is a City
# Resultant first title: Back Fire, Query Title: Backfire!
# Resultant first title: Tom and Huck, Query Title: Tom and Huck
# Resultant first title: A Gathering of Eagles, Query Title: Operation Cross Eagles
# Resultant first title: Insaan Jaag Utha, Query Title: Insaan Jaag Utha
# Resultant first title: How I Was Systematically Destroyed by an Idiot, Query Title: How I Was Systematically Destroyed by an Idiot
# Resultant first title: Major Barbara, Query Title: Doña Bárbara
# Resultant first title: Death at a Funeral, Query Title: The Funeral
# Resultant first title: The Pirate of Panama, Query Title: Pirates of the Sky
# Resultant first title: Exotica, Query Title: The Exotic Ones
# Resultant first title: Hey Ram, Query Title: Hey Ram
# Resultant first title: Journey Back to Oz, Query Title: Return to Oz
# Resultant first title: Pulp Fiction, Query Title: Pulp Fiction
# Resultant first title: La violetera, Query Title: La violetera
# Resultant first title: The Princess and the Warrior, Query Title: The Princess and the Warrior
# Resultant first title: Demoniac, Query Title: Bernardine
# Resultant first title: The Terror, Query Title: The Terror
# Resultant first title: On s'en fout... nous on s'aime, Query Title: On s'en fout... nous on s'aime
# Resultant first title: The Last of Mrs. Cheyney, Query Title: The Last of Mrs. Cheyney
# Resultant first title: Little Miss Smiles, Query Title: Little Miss Smiles
# Resultant first title: Sleep, Query Title: Never Sleep Again
# Resultant first title: A Fig Leaf for Eve, Query Title: The Seed of the Sacred Fig
# Resultant first title: A Bronx Tale, Query Title: A Bronx Tale
# Resultant first title: Crumb, Query Title: The Crumbs
# Resultant first title: Real Genius, Query Title: Real Genius
# Resultant first title: The Beautiful Blonde from Bashful Bend, Query Title: The Beautiful Blonde from Bashful Bend
# Resultant first title: Herbie Rides Again, Query Title: Herbie Rides Again
# Resultant first title: A Shriek in the Night, Query Title: A Shriek in the Night
# Resultant first title: Generation Wealth, Query Title: Wealth
# Resultant first title: Whitey: United States of America v. James J. Bulger, Query Title: Whitey: United States of America v. James J. Bulger
# Resultant first title: Where the Red Fern Grows, Query Title: Where the Red Fern Grows
# Resultant first title: Crouching Tiger, Hidden Dragon, Query Title: Crouching Tiger, Hidden Dragon
# Resultant first title: In Pursuit of Silence, Query Title: The Silence
# Resultant first title: To the Stars by Hard Ways, Query Title: Heliotrope
# Resultant first title: The Carpetbaggers, Query Title: Operation Carpetbagger
# Resultant first title: The Hideout, Query Title: The Hideout
# Resultant first title: The Old Guard 2, Query Title: The Old Guard
# Resultant first title: Disturbing the Peace, Query Title: Disturbing the Peace
# Resultant first title: Lady Macbeth, Query Title: Lady Macbeth
# Resultant first title: What's Up Superdoc!, Query Title: The Super Sex
# Resultant first title: The Frontiersmen, Query Title: The Frontiersmen
# Resultant first title: In the Wink of an Eye, Query Title: A Wink and a Smile
# Resultant first title: Condorito: The Movie, Query Title: Condorito: The Movie
# Resultant first title: Indranath Srikanta O Annadadidi, Query Title: Indranath Srikanta O Annadadidi
# Resultant first title: The Omega Code, Query Title: Omega Doom
# Resultant first title: Campfire Tales, Query Title: Campfire Tales
# Resultant first title: Sailing Along, Query Title: The Lonely White Sail
# Resultant first title: Bye Bye Birdie, Query Title: Goodbye, See You Tomorrow
# Resultant first title: Ao Redor do Brasil, Query Title: Ao Redor do Brasil
# Resultant first title: Floating, Query Title: What Doesn't Float
# Resultant first title: Bar 20 Rides Again, Query Title: Bar 20 Rides Again
# Resultant first title: Beautiful Creatures, Query Title: Beautiful Creatures
# Resultant first title: Denial, Query Title: Sara
# Resultant first title: Monkey Grip, Query Title: Monkey Grip
# Resultant first title: Mugabe and the White African, Query Title: Mugabe and the White African
# Resultant first title: Forever, Query Title: Forever Strong
# Resultant first title: Justice of the Far North, Query Title: Justice of the Far North
# Resultant first title: Marecek, Pass Me the Pen!, Query Title: Marecek, Pass Me the Pen!
# Resultant first title: Hercules Against Rome, Query Title: Hercules Against Rome
# Resultant first title: Disturbing the Peace, Query Title: Disturbing the Peace
# Resultant first title: Curse of the Fly, Query Title: Curse of the Fly
# Resultant first title: When Women Lost Their Tails, Query Title: When Women Lost Their Tails
# Resultant first title: Dharti Ke Lal, Query Title: You Should Have Left
# Resultant first title: The Emperor and the Assassin, Query Title: The Emperor and the Assassin
# Resultant first title: Love Me Twice, Query Title: Love Me Twice
# Resultant first title: High Tide, Query Title: High Season
# Resultant first title: Al caer la tarde..., Query Title: Al caer la tarde...
# Resultant first title: Kartavya, Query Title: Kartavya
# Resultant first title: Cyber Vengeance, Query Title: Cyber Vengeance
# Resultant first title: Heart of Champions, Query Title: Heart of Champions
# Resultant first title: An Eye for an Eye, Query Title: Eye for an Eye
# Resultant first title: The Housemaid, Query Title: The Milkmaid
# Resultant first title: A Trick of Hearts, Query Title: Marooned Hearts
# Resultant first title: Pratighatana, Query Title: Pratiggya
# Resultant first title: Vallah Kya Baat Hai, Query Title: Vallah Kya Baat Hai
# Resultant first title: The Jazz Singer, Query Title: The Jazz Singer
# Resultant first title: Rosalba, la fanciulla di Pompei, Query Title: Rosalba, la fanciulla di Pompei
# Resultant first title: Huracán Ramírez, Query Title: Huracán Ramírez
# Resultant first title: The Age of Disclosure, Query Title: Disclosure
# Resultant first title: The Further Adventures of the Wilderness Family, Query Title: Family Pack
# Resultant first title: What You Wish For, Query Title: What You Wish For
# Resultant first title: Earthquake, Query Title: Earthquake
# Resultant first title: The Prowler, Query Title: The Prowler
# Resultant first title: My Virgin, Query Title: Virgin
# Resultant first title: The Last House on the Left, Query Title: The Last House on the Left
# Resultant first title: One Missed Call, Query Title: One Missed Call
# Resultant first title: Arranged Marriage, Query Title: Arranged Marriage
# Resultant first title: The Last Princess, Query Title: The Last Princess
# Resultant first title: Filosofská historie, Query Title: Filosofská historie
# Resultant first title: Defying Gravity, Query Title: Laws of Gravity
# Resultant first title: The Song of Life, Query Title: Life Stinks
# Resultant first title: Duffy of San Quentin, Query Title: Duffy of San Quentin
# Resultant first title: My Grandmother, Query Title: Grandma
# Resultant first title: The Day Shall Come, Query Title: That'll Be the Day
# Resultant first title: Una familia de tantas, Query Title: Una familia de tantas
# Resultant first title: Last Summer, Query Title: Last Summer
# Resultant first title: The Stranger, Query Title: Not as a Stranger
# Resultant first title: The Jacket, Query Title: The Jacket
# Resultant first title: Blackmail, Query Title: Blackmail
# Resultant first title: Josephine and Men, Query Title: Josephine and Men
# Resultant first title: An Unfinished Film, Query Title: A Film Unfinished
# Resultant first title: 1917, Query Title: 1915
# Resultant first title: Prince Nezha's Triumph Against Dragon King, Query Title: Prince Nezha's Triumph Against Dragon King
# Resultant first title: Caltiki, the Immortal Monster, Query Title: Caltiki, the Immortal Monster
# Resultant first title: Black Fist, Query Title: Black Fist
# Resultant first title: Boy, the Noszty, Query Title: Boy, the Noszty
# Resultant first title: Hollywood Shuffle, Query Title: Hollywood Shuffle
# Resultant first title: Namu, the Killer Whale, Query Title: Namu, the Killer Whale
# Resultant first title: The Legend of an Erotic Movie Star, Query Title: The Legend of an Erotic Movie Star
# Resultant first title: Can She Bake a Cherry Pie?, Query Title: Can She Bake a Cherry Pie?
# Resultant first title: The Prey, Query Title: The Prey
# Resultant first title: Devil Fetus, Query Title: Devil Monster
# Resultant first title: Color Me Blood Red, Query Title: Blood Red Rose
# Resultant first title: Give Me Your Hand, Query Title: Hands Up!
# Resultant first title: The Scopone Game, Query Title: The Scopone Game
# Resultant first title: Otto Lara Rezende ou... Bonitinha, Mas Ordinária, Query Title: Otto Lara Rezende ou... Bonitinha, Mas Ordinária
# Resultant first title: Winners of the Wilderness, Query Title: Winners of the Wilderness
# Resultant first title: They Come to America, Query Title: Coming to America
# Resultant first title: Maries Lied, Query Title: Marie
# Resultant first title: It Should Happen to You, Query Title: It Might Happen to You
# Resultant first title: Savage Man Savage Beast, Query Title: Savage Hunt
# Resultant first title: Mean Streets, Query Title: Mean Streets
# Resultant first title: Darna, Query Title: Stigmata
# Resultant first title: Wavelength, Query Title: Wavelength
# Resultant first title: The Gatekeeper, Query Title: The Gatekeeper
# Resultant first title: Os Bons Tempos Voltaram: Vamos Gozar Outra Vez, Query Title: Os Bons Tempos Voltaram: Vamos Gozar Outra Vez
# Resultant first title: Young Sherlock Holmes, Query Title: Young Sherlock Holmes
# Resultant first title: The Favour, the Watch and the Very Big Fish, Query Title: The Favour, the Watch and the Very Big Fish
# Resultant first title: Mother of a Day, Query Title: 'night, Mother
# Resultant first title: Stalingrad, Query Title: Stalingrad
# Resultant first title: Kâen no tsuzumî, Query Title: Kâen no tsuzumî
# Resultant first title: The Mostly Unfabulous Social Life of Ethan Green, Query Title: The Mostly Unfabulous Social Life of Ethan Green
# Resultant first title: Atlantis: The Lost Empire, Query Title: Atlantis
# Resultant first title: The Jack Rider, Query Title: The Jack Rider
# Resultant first title: A Simple Wish, Query Title: A Simple Wish
# Resultant first title: Our Kind of Traitor, Query Title: Our Kind of Traitor
# Resultant first title: Body Parts, Query Title: Body Parts
# Resultant first title: The Little Mermaid, Query Title: The Little Mermaid
# Resultant first title: Smile, Query Title: Smiles Are Trumps
# Resultant first title: Marriage in Name Only, Query Title: Wife in Name Only
# Resultant first title: Around the World Under the Sea, Query Title: Around the World Under the Sea
# Resultant first title: Species II, Query Title: Species II
# Resultant first title: Bereavement, Query Title: Bereavement
# Resultant first title: Ali Baba and 40 Thieves, Query Title: Ali Baba and the Forty Thieves
# Resultant first title: Speedway, Query Title: Indianapolis Speedway
# Resultant first title: La norteña de mis amores, Query Title: En ny dag gryer
# Resultant first title: Victoria the Great, Query Title: Victoria the Great
# Resultant first title: A Nightmare on Elm Street 4: The Dream Master, Query Title: A Nightmare on Elm Street 4: The Dream Master
# Resultant first title: Love Bites, Query Title: Love Bites
# Resultant first title: La mia signora, Query Title: La mia signora
# Resultant first title: Under Siege 2: Dark Territory, Query Title: Under Siege
# Resultant first title: Sex Clinic '74, Query Title: Sex Service
# Resultant first title: The Getaway, Query Title: A Perfect Getaway
# Resultant first title: Anaconda, Query Title: Anaconda
# Resultant first title: The Leopard Woman, Query Title: The Leopardess
# Resultant first title: Ek Vivaah... Aisa Bhi, Query Title: Ek Vivaah... Aisa Bhi
# Resultant first title: Beach House, Query Title: Beach House
# Resultant first title: Mademoiselle Midnight, Query Title: Mademoiselle Midnight
# Resultant first title: Don't Look in the Basement, Query Title: Don't Look in the Basement
# Resultant first title: An Ideal Husband, Query Title: An Ideal Husband
# Resultant first title: The Wrong Mr. Wright, Query Title: The Wrong Mr. Wright
# Resultant first title: Leaving Neverland 2: Surviving Michael Jackson, Query Title: Leaving Neverland 2: Surviving Michael Jackson
# Resultant first title: Biggles: Adventures in Time, Query Title: Biggles: Adventures in Time
# Resultant first title: Can't Help Singing, Query Title: The Help
# Resultant first title: The Cross and the Switchblade, Query Title: Cross-Examination
# Resultant first title: The Way to the Gold, Query Title: Gold Is Where You Find It
# Resultant first title: X2: X-Men United, Query Title: www.XXX.com
# Resultant first title: Honor Society, Query Title: Honor First
# Resultant first title: Edge of Tomorrow, Query Title: Patch Adams
# Resultant first title: The Loyal 47 Ronin, Query Title: The Loyal 47 Ronin
# Resultant first title: Berlin - Ecke Schönhauser, Query Title: Die schönsten Beine von Berlin
# Resultant first title: The Victim, Query Title: The Victim
# Resultant first title: Kentucky Jubilee, Query Title: Kentucky Jubilee
# Resultant first title: The Lost City, Query Title: The Lost City
# Resultant first title: Gentleman Joe Palooka, Query Title: Gentleman Joe Palooka
# Resultant first title: Raiders from Beneath the Sea, Query Title: Mystery Sea Raider
# Resultant first title: The Phantom Rider, Query Title: The Phantom Rider
# Resultant first title: Dirty Work, Query Title: Dirty Work
# Resultant first title: The Desert Hawk, Query Title: The Desert Hawk
# Resultant first title: Coupe de Ville, Query Title: Coupe de Ville
# Resultant first title: Family Resemblances, Query Title: Frenchie
# Resultant first title: Submarine, Query Title: Submarine
# Resultant first title: Days of Jesse James, Query Title: Days of Jesse James
# Resultant first title: Two Kinds of Women, Query Title: Two Kinds of Women
# Resultant first title: On Thin Ice, Query Title: Thin Ice
# Resultant first title: Bang Bang, Query Title: Bang Bang
# Resultant first title: Kleinhoff Hotel, Query Title: Kleinhoff Hotel
# Resultant first title: 12 Years a Slave, Query Title: Slaves of New York
# Resultant first title: If I Can't Have Love, I Want Power, Query Title: For the Moment
# Resultant first title: Basic Instinct, Query Title: Basic Instinct
# Resultant first title: James' Journey to Jerusalem, Query Title: Journey to Jerusalem
# Resultant first title: Edge of Darkness, Query Title: Edge of Darkness
# Resultant first title: The Young Messiah, Query Title: Testament of Youth
# Resultant first title: The Sword of El Cid, Query Title: El Cid
# Resultant first title: American Promise, Query Title: American Promise
# Resultant first title: Grande école, Query Title: Grande école
# Resultant first title: Bang Bang, Query Title: Chitty Chitty Bang Bang
# Resultant first title: Santa Claus, Query Title: Dear Santa
# Resultant first title: The Guilty, Query Title: Without Apparent Motive
# Resultant first title: Hollywood Story, Query Title: Film Without a Name
# Resultant first title: Hollywood Cowboy, Query Title: Hollywood Cowboy
# Resultant first title: State Property: Blood on the Streets, Query Title: State Property: Blood on the Streets
# Resultant first title: White Oleander, Query Title: The Better 'Ole
# Resultant first title: American Socialist: The Life and Times of Eugene Victor Debs, Query Title: American Socialist: The Life and Times of Eugene Victor Debs
# Resultant first title: I'm Going Home, Query Title: Just like Home
# Resultant first title: Rank, Query Title: One Inch from Victory
# Resultant first title: Lilo & Stitch, Query Title: Lilo & Stitch
# Resultant first title: O Camelô da Rua Larga, Query Title: O Camelô da Rua Larga
# Resultant first title: Maharaja, Query Title: Maharaja
# Resultant first title: The Mystery of the 13th Guest, Query Title: The Mystery of the 13th Guest
# Resultant first title: Blackmailed Wives, Query Title: Blackmailed Wives
# Resultant first title: Tera Mera Ki Rishta, Query Title: Libera, My Love
# Resultant first title: You're a Lucky Fellow, Mr. Smith, Query Title: You're a Lucky Fellow, Mr. Smith
# Resultant first title: Pianoforte, Query Title: Pianoforte
# Resultant first title: With Sitting Bull at the Spirit Lake Massacre, Query Title: With Sitting Bull at the Spirit Lake Massacre
# Resultant first title: Denise Calls Up, Query Title: Denise Calls Up
# Resultant first title: Agent, Query Title: Rogue Agent
# Resultant first title: Star in the Dust, Query Title: Star in the Dust
# Resultant first title: Stealing America: Vote by Vote, Query Title: Stealing America: Vote by Vote
# Resultant first title: The Raven, Query Title: The Raven
# Resultant first title: The Call of the Savage, Query Title: The Call of the Savage
# Resultant first title: The Mysterious Mr. Wong, Query Title: The Mystery of Mr. Wong
# Resultant first title: The Strangler, Query Title: The Strangler
# Resultant first title: Bona, Query Title: Trotta
# Resultant first title: Message in a Bottle, Query Title: Message in a Bottle
# Resultant first title: Raznye sudby, Query Title: Raznye sudby
# Resultant first title: Showing Up, Query Title: Showing Up
# Resultant first title: Cup Fever, Query Title: Pep Squad
# Resultant first title: Kill or Be Killed, Query Title: Kill or Be Killed
# Resultant first title: Gulliver's Travels, Query Title: Gulliver's Travels
# Resultant first title: Madly in Love, Query Title: Madly in Love
# Resultant first title: Dancing at the Blue Iguana, Query Title: Dancing at the Blue Iguana
# Resultant first title: Down Periscope, Query Title: Down Periscope
# Resultant first title: God of Gamblers II, Query Title: God of Gamblers II
# Resultant first title: Mrs. Parker and the Vicious Circle, Query Title: Mrs. Parker and the Vicious Circle
# Resultant first title: The Enemy General, Query Title: The General
# Resultant first title: I'll Be Right There, Query Title: I'll Be Right There
# Resultant first title: Il Grande Sentiero, Query Title: Il Grande Sentiero
# Resultant first title: The Girl from Rio, Query Title: The Girl from Rio
# Resultant first title: Songs and Saddles, Query Title: Saddle Serenade
# Resultant first title: Portrait of Jason, Query Title: Portrait of Jason
# Resultant first title: Bohème - Künstlerliebe, Query Title: Bohème - Künstlerliebe
# Resultant first title: Gun Smoke, Query Title: Gun Smoke
# Resultant first title: Sense and Sensibility, Query Title: Sense and Sensibility
# Resultant first title: 4 Devils, Query Title: The Devil's Circus
# Resultant first title: The Mysterious Monsters, Query Title: The Mysterious Monsters
# Resultant first title: Something Wild, Query Title: The Wild Scene
# Resultant first title: Mondays in the Sun, Query Title: Nights and Weekends
# Resultant first title: The Night of the Scorpion, Query Title: The Night of the Scorpion
# Resultant first title: Blood Bride, Query Title: Blood Bride
# Resultant first title: The Vanished, Query Title: #MissingCouple
# Resultant first title: Wilder vs. Ortiz, Query Title: Wilder vs. Ortiz
# Resultant first title: The House, Query Title: Neighborhood House
# Resultant first title: Devil's Partner, Query Title: My Friend the Devil
# Resultant first title: The Spider Returns, Query Title: The Spider
# Resultant first title: Fear in the Night, Query Title: Fear in the Night
# Resultant first title: Big Jim McLain, Query Title: Big Jim McLain
# Resultant first title: How They Make Adult Movies, Query Title: How They Make Adult Movies
# Resultant first title: Nothing Lasts Forever, Query Title: Nothing Lasts Forever
# Resultant first title: Stuck on You!, Query Title: Issues
# Resultant first title: Far til fire og onkel Sofus, Query Title: Far til fire og onkel Sofus
# Resultant first title: Totò a colori, Query Title: Totò a colori
# Resultant first title: Luca, Query Title: Luca
# Resultant first title: Avanti!, Query Title: Avanti!
# Resultant first title: Apolytrosis, Query Title: Apolytrosis
# Resultant first title: The Flaming Teenage, Query Title: Chronicle of Flaming Years
# Resultant first title: The Ridin' Kid from Powder River, Query Title: The Ridin' Kid from Powder River
# Resultant first title: The King's Highway, Query Title: The King's Highway
# Resultant first title: Pacific Banana, Query Title: Banana Ridge
# Resultant first title: 350 Days - Legends. Champions. Survivors, Query Title: Two Days
# Resultant first title: Gay Sex in the 70s, Query Title: Gay USA
# Resultant first title: The Bandolero, Query Title: The Bandolero
# Resultant first title: The Birthday Party, Query Title: The Birthday Party
# Resultant first title: Naked Over the Fence, Query Title: Naked Over the Fence
# Resultant first title: Wedding in Malinovka, Query Title: Wedding in Malinovka
# Resultant first title: Baaghi, Query Title: Boshuri siskhli
# Resultant first title: Deux heures moins le quart avant Jésus-Christ, Query Title: Deux heures moins le quart avant Jésus-Christ
# Resultant first title: Pilot X, Query Title: Pilot X
# Resultant first title: Ghost-Town Gold, Query Title: Ghost-Town Gold
# Resultant first title: Money for Nothing, Query Title: Nobody's Money
# Resultant first title: Martian Child, Query Title: Martian Child
# Resultant first title: Lady in White, Query Title: The Lady in White
# Resultant first title: The Alley Cats, Query Title: Peacock Alley
# Resultant first title: The Girl in Lovers Lane, Query Title: Lovers' Lane
# Resultant first title: Hobo with a Shotgun, Query Title: Gung Ho
# Resultant first title: The Rookie's Return, Query Title: Rookies
# Resultant first title: The Montecarlo Story, Query Title: The Montecarlo Story
# Resultant first title: The World Is Full of Married Men, Query Title: If All the Guys in the World...
# Resultant first title: Just Before Dawn, Query Title: Just Before Dawn
# Resultant first title: Cashback, Query Title: Cashback
# Resultant first title: Pour un soir..!, Query Title: Aproape de soare
# Resultant first title: Escapade in Florence, Query Title: Escapade in Florence
# Resultant first title: Sing Me a Love Song, Query Title: Sing Me a Love Song
# Resultant first title: Personal Services, Query Title: Personal Services
# Resultant first title: Ewiger Wald, Query Title: Eifersucht
# Resultant first title: Woman Times Seven, Query Title: 7 Women
# Resultant first title: The Japanese Wife Next Door: Part 2, Query Title: The Japanese Wife Next Door
# Resultant first title: The Adventures of Mr. Pickwick, Query Title: The Adventures of Mr. Pickwick
# Resultant first title: Our Folks, Query Title: Vozdushnyy izvozchik
# Resultant first title: All's Faire in Love, Query Title: All's Faire in Love
# Resultant first title: No Room at the Inn, Query Title: The War Room
# Resultant first title: The Telegraph Trail, Query Title: The Telegraph Trail
# Resultant first title: I Became a Criminal, Query Title: I Became a Criminal
# Resultant first title: Kireedam, Query Title: Kireedam
# Resultant first title: Boy Erased, Query Title: Boy Erased
# Resultant first title: The Underwater City, Query Title: Underwater
# Resultant first title: The Hypnotic Eye, Query Title: Hypnotic
# Resultant first title: Sommerglæder, Query Title: Sommerglæder
# Resultant first title: Traveling Husbands, Query Title: The First Traveling Saleslady
# Resultant first title: Adolescencia, Query Title: Adolescencia
# Resultant first title: Come Back, Africa, Query Title: Come Back, Africa
# Resultant first title: Bangistan, Query Title: Bangistan
# Resultant first title: The Bell Jar, Query Title: The Jar
# Resultant first title: Dirty Dancing: Havana Nights, Query Title: Dirty Dancing: Havana Nights
# Resultant first title: Home Before Midnight, Query Title: City After Midnight
# Resultant first title: Volcano, Query Title: Volcano
# Resultant first title: Creature with the Blue Hand, Query Title: Creature with the Blue Hand
# Resultant first title: Lost in Paris, Query Title: Lost in Paris
# Resultant first title: Equals, Query Title: Love and Other Catastrophes
# Resultant first title: Much Ado About Nothing, Query Title: Much Ado About Nothing
# Resultant first title: The Gorgon, Query Title: Gorgo
# Resultant first title: Season of Passion, Query Title: Season of Passion
# Resultant first title: The Dark Hours, Query Title: The Dark Hour
# Resultant first title: Bohemian Rhapsody, Query Title: Rhapsody
# Resultant first title: Severance, Query Title: Severance
# Resultant first title: The Men's Club, Query Title: Know Your Men
# Resultant first title: Spitfire, Query Title: Spitfire
# Resultant first title: Secret Lives: Hidden Children and Their Rescuers During WWII, Query Title: Clandestine Childhood
# Resultant first title: Kâen no tsuzumî, Query Title: Kundun
# Resultant first title: Tense Moments from Opera, Query Title: Tense Moments from Opera
# Resultant first title: The Count of Monte Cristo - Part 2: Retribution, Query Title: The Count of Monte Cristo
# Resultant first title: The Boxcar Children - Surprise Island, Query Title: The Boxcar Children - Surprise Island
# Resultant first title: Balls of Fury, Query Title: Balls of Fury
# Resultant first title: El alazán y el rosillo, Query Title: Omm el Saad
# Resultant first title: Fine Feathers, Query Title: Fine Feathers
# Resultant first title: Touch, Query Title: Caressed
# Resultant first title: Honeymoon Horror, Query Title: Honeymoon Horror
# Resultant first title: Les cinq gentlemen maudits, Query Title: Les cinq gentlemen maudits
# Resultant first title: The Shiver of the Vampires, Query Title: The Shiver of the Vampires
# Resultant first title: Pajama Party, Query Title: Pajama Party
# Resultant first title: Buddy, Query Title: Barken Margrethe
# Resultant first title: Gardens of the Night, Query Title: Gardens of the Night
# Resultant first title: Sahara, Query Title: Sahara
# Resultant first title: Babe Watch: Forbidden Parody, Query Title: Babe Watch: Forbidden Parody
# Resultant first title: La vida no vale nada, Query Title: Toda una vida
# Resultant first title: Sweet Sugar, Query Title: Sweet Sugar
# Resultant first title: Forced Vengeance, Query Title: Forced Vengeance
# Resultant first title: People on Sunday, Query Title: One Wonderful Sunday
# Resultant first title: Where the Heart Is, Query Title: Paper Heart
# Resultant first title: The Bed and How to Make It!, Query Title: She Made Her Bed
# Resultant first title: Fearless, Query Title: Fearless
# Resultant first title: Double Impact, Query Title: The Twins Effect
# Resultant first title: The Black Waters of Echo's Pond, Query Title: Black Waters
# Resultant first title: The Photographer, Query Title: The Photographer
# Resultant first title: Rome Express, Query Title: Rome Express
# Resultant first title: Girl Without a Room, Query Title: Girl Without a Room
# Resultant first title: Heal, Query Title: Heal
# Resultant first title: Something to Sing About, Query Title: Sing and Like It
# Resultant first title: Spark: A Space Tail, Query Title: Spark: A Space Tail
# Resultant first title: The Yes Girls, Query Title: The Girl Said No
# Resultant first title: Sirocco, Query Title: Sirocco
# Resultant first title: The Eternal Flame, Query Title: The Eternal Flame
# Resultant first title: Die Halbzarte, Query Title: Die Halbzarte
# Resultant first title: Scattered Clouds, Query Title: Scattered Clouds
# Resultant first title: Inside Llewyn Davis, Query Title: Inside Llewyn Davis
# Resultant first title: I din fars lomme, Query Title: I din fars lomme
# Resultant first title: Chicago Cab, Query Title: Chicago Cab
# Resultant first title: The Trial of Billy Jack, Query Title: The Trial of Billy Jack
# Resultant first title: A Trick of Hearts, Query Title: Hearts Up
# Resultant first title: 13 Fanboy, Query Title: 13 Fanboy
# Resultant first title: He Couldn't Take It, Query Title: He Couldn't Take It
# Resultant first title: The Case of the Howling Dog, Query Title: The Case of the Howling Dog
# Resultant first title: Butterflies in the Rain, Query Title: Butterflies in the Rain
# Resultant first title: Eight Deadly Shots, Query Title: 16 Blocks
# Resultant first title: Samson, Query Title: Samson
# Resultant first title: Collide, Query Title: Intersection
# Resultant first title: Romance on the High Seas, Query Title: Romance on the High Seas
# Resultant first title: Dot and the Kangaroo, Query Title: Dot and the Kangaroo
# Resultant first title: Le fil à la patte, Query Title: Le fil à la patte
# Resultant first title: Totò e Peppino divisi a Berlino, Query Title: Totò e Peppino divisi a Berlino
# Resultant first title: Hjärtats röst, Query Title: Hjärtats röst
# Resultant first title: Fingerprints Don't Lie, Query Title: Fingerprints Don't Lie
# Resultant first title: The Duke Steps Out, Query Title: Duke of Chicago
# Resultant first title: El Bronco, Query Title: El Bronco
# Resultant first title: The Diamond Queen, Query Title: The Diamond Queen
# Resultant first title: Mashaal, Query Title: Mashaal
# Resultant first title: Man or Gun, Query Title: Man with the Gun
# Resultant first title: Monster a Go-Go, Query Title: Monster a Go-Go
# Resultant first title: Un sac de billes, Query Title: Un sac de billes
# Resultant first title: Lonely Are the Brave, Query Title: Lonely Are the Brave
# Resultant first title: History of Jazz: Oxygen for the Ears, Query Title: The Ear
# Resultant first title: Lorna's Silence, Query Title: Lorna's Silence
# Resultant first title: London Melody, Query Title: The Melody Man
# Resultant first title: The Gorilla, Query Title: The Gorilla
# Resultant first title: Nightflyers, Query Title: Nightflyers
# Resultant first title: When Do We Eat?, Query Title: Good Manners
# Resultant first title: Video Games: The Movie, Query Title: Video Games: The Movie
# Resultant first title: Goldengirl, Query Title: Goldengirl
# Resultant first title: Race for Glory, Query Title: Triumph
# Resultant first title: Devil Fetus, Query Title: Devil Fetus
# Resultant first title: Something Wicked This Way Comes, Query Title: Wicked World
# Resultant first title: The Sixth Man, Query Title: Mr. Six
# Resultant first title: Een vrouw tussen hond en wolf, Query Title: Een vrouw tussen hond en wolf
# Resultant first title: Devilman, Query Title: Devilman
# Resultant first title: Undine, Query Title: Undine
# Resultant first title: L'alcova, Query Title: L'alcova
# Resultant first title: What Becomes of the Broken Hearted?, Query Title: What Becomes of the Broken Hearted?
# Resultant first title: Trishul, Query Title: Jiban Trishna
# Resultant first title: Talpuk alatt fütyül a szél, Query Title: Atlantik
# Resultant first title: Mandinga, Query Title: Mandinga
# Resultant first title: Cirkus Fandango, Query Title: Cirkus Fandango
# Resultant first title: Don't Worry, We'll Think of a Title, Query Title: Don't Panic Chaps
# Resultant first title: Mandir, Query Title: Mandir
# Resultant first title: Lucía, Lucía, Query Title: Lucia
# Resultant first title: Lust in the Swamps, Query Title: Swades
# Resultant first title: Smart Woman, Query Title: Heroes and Husbands
# Resultant first title: Saat Pake Bandha, Query Title: Latt Saheb
# Resultant first title: O Ébrio, Query Title: O Ébrio
# Resultant first title: Sweethearts of the Prison Rodeo, Query Title: Sweethearts of the Prison Rodeo
# Resultant first title: Forced Landing, Query Title: Forced Landing
# Resultant first title: Where Trails Divide, Query Title: Where Trails Divide
# Resultant first title: Andaaz, Query Title: Love, Honor and Behave
# Resultant first title: The Games, Query Title: Marathon
# Resultant first title: Naked Over the Fence, Query Title: Over Exposed
# Resultant first title: The Boy and the World, Query Title: The Boy
# Resultant first title: Earth: One Amazing Day, Query Title: Earth: One Amazing Day
# Resultant first title: Endless Poetry, Query Title: Endless Poetry
# Resultant first title: Caged Women, Query Title: Caged Women II
# Resultant first title: The Bride with White Hair, Query Title: The Bride with White Hair
# Resultant first title: Penitentiary II, Query Title: Penitentiary
# Resultant first title: The Flaming Signal, Query Title: The Flaming Signal
# Resultant first title: Fanfaren der Liebe, Query Title: Fanfaren der Liebe
# Resultant first title: Frankenstein '80, Query Title: Frankenstein '80
# Resultant first title: Away We Go, Query Title: Home and Away
# Resultant first title: Vivre sa vie, Query Title: Cycle Vixens
# Resultant first title: 18+: True Love Never Dies, Query Title: Welcome to 18
# Resultant first title: No Trees in the Street, Query Title: Elstree Calling
# Resultant first title: The Things of Life, Query Title: Damaged Lives
# Resultant first title: Miss Hokusai, Query Title: Miss Hokusai
# Resultant first title: High Voltage, Query Title: High Voltage
# Resultant first title: A Story from Chikamatsu, Query Title: A Story from Chikamatsu
# Resultant first title: Oscar and Lucinda, Query Title: Oscar and Lucinda
# Resultant first title: Run, Man, Run, Query Title: Run, Man, Run
# Resultant first title: Pink Motel, Query Title: Pink Motel
# Resultant first title: Emma, Query Title: Emma Mae
# Resultant first title: Cindy's Love Games, Query Title: Cindy's Love Games
# Resultant first title: The Red Rope, Query Title: The Red Rope
# Resultant first title: Amor de Perdição, Query Title: Amor de Perdição
# Resultant first title: Deception, Query Title: Deception
# Resultant first title: The Nest of the Cuckoo Birds, Query Title: The Nest of the Cuckoo Birds
# Resultant first title: Nabeshima kaibyô-den, Query Title: Nabeshima kaibyô-den
# Resultant first title: Nache Nagin Gali Gali, Query Title: Nagin
# Resultant first title: Examined Life, Query Title: A Life in the Balance
# Resultant first title: We Are What We Are, Query Title: Us Two
# Resultant first title: Do Bhai, Query Title: Do Bhai
# Resultant first title: The Bold Caballero, Query Title: The Bold Caballero
# Resultant first title: Enter the Void, Query Title: The Void
# Resultant first title: Tales of Robin Hood, Query Title: Robin Hood
# Resultant first title: Pour un soir..!, Query Title: Le due sorelle
# Resultant first title: One Good Cop, Query Title: A Special Cop in Action
# Resultant first title: Escape from Hell Island, Query Title: Escape from Hell
# Resultant first title: Romance of the Rio Grande, Query Title: West of the Rio Grande
# Resultant first title: The True Story of Lynn Stuart, Query Title: The True Story of Lynn Stuart
# Resultant first title: Flames, Query Title: Firebrand
# Resultant first title: The Necessary Evil, Query Title: Absence of Malice
# Resultant first title: Mystery Junction, Query Title: Mystery Junction
# Resultant first title: Female Teacher: In Front of the Students, Query Title: Female Teacher
# Resultant first title: Drive Angry, Query Title: Drive Angry
# Resultant first title: Daredevil in the Castle, Query Title: Daredevil in the Castle
# Resultant first title: Gunless, Query Title: Gunless
# Resultant first title: Sandman, Query Title: Sandman
# Resultant first title: Twenty Plus Two, Query Title: Twenty Plus Two
# Resultant first title: The Red Violin, Query Title: The Violin
# Resultant first title: One Way Out, Query Title: One Way Out
# Resultant first title: An American Tail: Fievel Goes West, Query Title: An American Tail: Fievel Goes West
# Resultant first title: Bollywood/Hollywood, Query Title: The Pretty Indian Girl
# Resultant first title: Born Winner, Query Title: Born to Win
# Resultant first title: The Beyond, Query Title: The Beyond
# Resultant first title: You Never Can Tell, Query Title: You Never Can Tell
# Resultant first title: Innamorata, Query Title: Innamorata
# Resultant first title: The Sinister Man, Query Title: The Sinister Man
# Resultant first title: Romancero marroquí, Query Title: Romancero marroquí
# Resultant first title: Invasion of the Saucer Men, Query Title: Invasion of the Saucer Men
# Resultant first title: The Ritual, Query Title: The Ritual
# Resultant first title: En este pueblo no hay ladrones, Query Title: El warda el baida
# Resultant first title: Blue Money, Query Title: Blue Money
# Resultant first title: Out All Night, Query Title: Out All Night
# Resultant first title: Chasing Einstein, Query Title: Chasing Einstein
# Resultant first title: Life in a Year, Query Title: Life in a Year
# Resultant first title: The Freebie, Query Title: Free, White and 21
# Resultant first title: Games of Desire, Query Title: Playthings of Desire
# Resultant first title: Philadelphia Experiment II, Query Title: The Experiment
# Resultant first title: The Son of Dr. Jekyll, Query Title: The Son of Dr. Jekyll
# Resultant first title: Working Girls, Query Title: Full Time Females
# Resultant first title: The Muse, Query Title: The Muse
# Resultant first title: Killing of the Flesh, Query Title: Killing of the Flesh
# Resultant first title: Forget Baghdad: Jews and Arabs - The Iraqi Connection, Query Title: Araby
# Resultant first title: Subway in the Sky, Query Title: Subway
# Resultant first title: Lucky Numbers, Query Title: Lucky Numbers
# Resultant first title: Steak (R)evolution, Query Title: Labbra serrate
# Resultant first title: The Addams Family, Query Title: The Addams Family
# Resultant first title: Dios no lo quiera, Query Title: Dios no lo quiera
# Resultant first title: Parada Paramount, Query Title: Parada Paramount
# Resultant first title: The Luckiest Man in America, Query Title: The Lucky Guy
# Resultant first title: The Meteor Man, Query Title: The Meteor Man
# Resultant first title: Kicking and Screaming, Query Title: Graduation
# Resultant first title: Treasure in Malta, Query Title: Treasure in Malta
# Resultant first title: The Private Lives of Adam and Eve, Query Title: The Private Lives of Adam and Eve
# Resultant first title: Frauen sind keine Engel, Query Title: Frauen sind keine Engel
# Resultant first title: 1918, Query Title: 1918
# Resultant first title: Take It or Leave It, Query Title: Take It or Leave It
# Resultant first title: Texas Trail, Query Title: Texas Trail
# Resultant first title: El gran amor de Bécquer, Query Title: El gran amor de Bécquer
# Resultant first title: Liebes-List und -Lust, Query Title: Liebes-List und -Lust
# Resultant first title: The Millerson Case, Query Title: The Millerson Case
# Resultant first title: Ankara - Heart of Turkey, Query Title: Ankara - Heart of Turkey
# Resultant first title: Nobody's Perfekt, Query Title: Nobody's Perfekt
# Resultant first title: Justice League: Crisis on Infinite Earths - Part Three, Query Title: Justice League: Crisis on Infinite Earths - Part One
# Resultant first title: 5 i 1/2 Bladego Józka, Query Title: J W Coop
# Resultant first title: The Middleton Family at the New York World's Fair, Query Title: At Middleton
# Resultant first title: Jim the Penman, Query Title: Jim the Penman
# Resultant first title: Logan, Query Title: Logan
# Resultant first title: The Pathfinder, Query Title: Pathfinder
# Resultant first title: Ten Little Indians, Query Title: Ten Little Indians
# Resultant first title: Death of a Corrupt Man, Query Title: The Corruptor
# Resultant first title: Long Day's Journey Into Night, Query Title: Such a Long Journey
# Resultant first title: The Rainbow, Query Title: Chasing Rainbows
# Resultant first title: Love Among the Millionaires, Query Title: Love Among the Millionaires
# Resultant first title: Night of Henna, Query Title: Henna
# Resultant first title: Chitralekha, Query Title: Chitralekha
# Resultant first title: The Mad Doctor of Market Street, Query Title: The Mad Doctor of Market Street
# Resultant first title: I Will Follow, Query Title: I Will Follow
# Resultant first title: Diminished Capacity, Query Title: Diminished Capacity
# Resultant first title: Startup.com, Query Title: The Founder
# Resultant first title: Little Accident, Query Title: Little Accident
# Resultant first title: Crazy People, Query Title: Get Crazy
# Resultant first title: WarGames, Query Title: Steamboy
# Resultant first title: Kept and Dreamless, Query Title: Kept and Dreamless
# Resultant first title: The Girl of the Limberlost, Query Title: A Girl of the Limberlost
# Resultant first title: Zamallu, Query Title: Zaytoun
# Resultant first title: Plain Clothes, Query Title: Fine Clothes
# Resultant first title: Frou-Frou, Query Title: Frisians in Peril
# Resultant first title: Pour un soir..!, Query Title: Il est plus facile pour un chameau...
# Resultant first title: Sensualidad, Query Title: Carlos
# Resultant first title: The Age of Disclosure, Query Title: Private Information
# Resultant first title: Temptation: Confessions of a Marriage Counselor, Query Title: Def by Temptation
# Resultant first title: Salute the Toff, Query Title: Salute the Toff
# Resultant first title: Tere Naal Love Ho Gaya, Query Title: Andha Naal
# Resultant first title: The Eel, Query Title: Prawo i piesc
# Resultant first title: Sing Me a Song of Texas, Query Title: Sing Me a Song of Texas
# Resultant first title: The Hidden Eye, Query Title: The Hidden Eye
# Resultant first title: El secreto de la mujer muerta, Query Title: La marca del muerto
# Resultant first title: Herod's Law, Query Title: Herod's Law
# Resultant first title: Ashima, Query Title: Ashima
# Resultant first title: Serial Mom, Query Title: Serial Mom
# Resultant first title: Teen Titans GO! To the Movies, Query Title: Teen Titans GO! To the Movies
# Resultant first title: The Second Woman, Query Title: Between Two Women
# Resultant first title: Il prete sposato, Query Title: Presto, abbracciatemi!
# Resultant first title: Micki + Maude, Query Title: Micki + Maude
# Resultant first title: Saawariya, Query Title: Saawariya
# Resultant first title: Devar Bhabhi, Query Title: Tjorven, Batsman, and Moses
# Resultant first title: A Clockwork Orange, Query Title: A Clockwork Orange
# Resultant first title: Captain America: The Winter Soldier, Query Title: Winter Soldier
# Resultant first title: You're in the Army Now, Query Title: In the Army Now
# Resultant first title: Joe MacBeth, Query Title: Joe MacBeth
# Resultant first title: Onu Affettim, Query Title: Dushmani: A Violent Love Story
# Resultant first title: The Secret of the Pueblo, Query Title: The Secret of the Pueblo
# Resultant first title: The Crimson Pirate, Query Title: The Crimson Pirate
# Resultant first title: Sant Dnyaneshwar, Query Title: Sant Dnyaneshwar
# Resultant first title: High Treason, Query Title: Guilty of Treason
# Resultant first title: Report to the Commissioner, Query Title: The Chapman Report
# Resultant first title: Girl Missing, Query Title: Girl Missing
# Resultant first title: Leave the World Behind, Query Title: Out of This World
# Resultant first title: The Olsen Gang Long Gone, Query Title: The Last Exploits of the Olsen Gang
# Resultant first title: Wu Tang vs. Ninja, Query Title: Wu Tang vs. Ninja
# Resultant first title: The Flame of Love, Query Title: Flame of My Love
# Resultant first title: Flame of Calcutta, Query Title: Flame of Calcutta
# Resultant first title: Silence of the North, Query Title: Out of the Silent North
# Resultant first title: The McConnell Story, Query Title: Sabre Jet
# Resultant first title: Don't Die: The Man Who Wants to Live Forever, Query Title: Immortality
# Resultant first title: Mongol: The Rise of Genghis Khan, Query Title: Genghis Khan and His Mongols
# Resultant first title: Maya, Query Title: Hari Maya
# Resultant first title: Tri vstrechi, Query Title: Tri vstrechi
# Resultant first title: Captain of the Guard, Query Title: Captain of the Guard
# Resultant first title: The Magnificent Two, Query Title: The Magnificent Two
# Resultant first title: I Am Divine, Query Title: I Am Divine
# Resultant first title: The Golden Lotus, Query Title: The Golden Lotus
# Resultant first title: Fat Albert, Query Title: Fat Albert
# Resultant first title: A Child for Sale, Query Title: Everything for Sale
# Resultant first title: Pratishodh, Query Title: Pratishodh
# Resultant first title: Mannequin, Query Title: S.A.-Mann Brand
# Resultant first title: Salome's Last Dance, Query Title: Salome's Last Dance
# Resultant first title: Dollar for Dollar, Query Title: Dollar
# Resultant first title: Tony Runs Wild, Query Title: Tony Runs Wild
# Resultant first title: Valhalla Rising, Query Title: Valhalla Rising
# Resultant first title: The Sword Stained with Royal Blood, Query Title: Crown of Thorns
# Resultant first title: Disaster Movie, Query Title: Flirting with Disaster
# Resultant first title: Seven Days... Seven Nights, Query Title: Seven Days... Seven Nights
# Resultant first title: The Education of Sonny Carson, Query Title: Sonny
# Resultant first title: Deli Yusuf, Query Title: Deli Yusuf
# Resultant first title: My Lady's Lips, Query Title: My Lady's Lips
# Resultant first title: All the President's Men, Query Title: All the President's Men
# Resultant first title: Entrails of a Virgin, Query Title: Entrails of a Virgin
# Resultant first title: Blood Debts, Query Title: Blood Debts
# Resultant first title: Heart of the West, Query Title: Hearts of the West
# Resultant first title: Vivre sa vie, Query Title: En vildfågel
# ...
# Resultant first title: Paul, Apostle of Christ, Query Title: The Apostle
# Resultant first title: Smarty, Query Title: Vicki
# Resultant first title: Midnight Sun, Query Title: The Midnight Sun
# Resultant first title: Knockout, Query Title: Knockouts
# Resultant first title: Larceny with Music, Query Title: Larceny with Music
# Resultant first title: The Girl from Woolworth's, Query Title: The Girl from Woolworth's
# Resultant first title: Covergirl, Query Title: Covergirl
# Resultant first title: The Long Memory, Query Title: Memory
# Resultant first title: My Blue Heaven, Query Title: My Blue Heaven
# Resultant first title: The Artist and the Model, Query Title: Artists and Models Abroad
# Resultant first title: That Lady in Ermine, Query Title: That Lady in Ermine
# Resultant first title: The Slasher, Query Title: The Slasher
# Resultant first title: Shake Hands with Murder, Query Title: Shake Hands with Murder
# Resultant first title: Bianca, Query Title: Bianca
# Resultant first title: High Crimes, Query Title: High Crimes
# Resultant first title: W starym dworku czyli niepodleglosc trójkatów, Query Title: Dziesieciu z Pawiaka
# Resultant first title: Peculiarities of the National Hunt, Query Title: Peculiarities of the National Hunt
# Resultant first title: I Don't Belong Anywhere: The Cinema of Chantal Akerman, Query Title: I Don't Belong Anywhere: The Cinema of Chantal Akerman
# Resultant first title: Fahriye Abla, Query Title: Absolon
# Resultant first title: Fantomas Unleashed, Query Title: Fantom Morrisvillu
# Resultant first title: Topper Takes a Trip, Query Title: Topper Takes a Trip
# Resultant first title: The Sun Also Rises, Query Title: The Sun Also Rises
# Resultant first title: Les tricheurs, Query Title: Les tricheurs
# Resultant first title: 365 Nights in Hollywood, Query Title: 365 Nights
# Resultant first title: Hawk the Slayer, Query Title: The Slayer
# Resultant first title: Lover of the Last Empress, Query Title: Lover of the Last Empress
# Resultant first title: Racing Stripes, Query Title: Racing Stripes
# Resultant first title: Flight of the Phoenix, Query Title: Flight of the Phoenix
# Resultant first title: Hamlet, Query Title: Johnny Hamlet
# Resultant first title: Warlock: The Armageddon, Query Title: Warlock: The Armageddon
# Resultant first title: Cruel Game, Query Title: A Cruel Romance
# Resultant first title: Maximum Overdrive, Query Title: Overexposed
# Resultant first title: The Prisoner of Zenda, Query Title: The King's Prisoner
# Resultant first title: Flubber, Query Title: Flubber
# Resultant first title: SAS: Rise of the Black Swan, Query Title: SAS: Rise of the Black Swan
# Resultant first title: A Place to Go, Query Title: Going Places
# Resultant first title: The Last of the High Kings, Query Title: The Last of the High Kings
# Resultant first title: All About Steve, Query Title: All About Steve
# Resultant first title: The Deadly Females, Query Title: The Deadly Females
# Resultant first title: Das Leben kann so schön sein, Query Title: Zirkus des Lebens
# Resultant first title: Nukkekauppias ja kaunis Lilith, Query Title: Nukitsamees
# Resultant first title: Crime and Punishment, Query Title: Crime and Punishment
# Resultant first title: Immacolata e Concetta, l'altra gelosia, Query Title: Biradari
# Resultant first title: I Drink Your Blood, Query Title: Mixed Blood
# Resultant first title: Haus des Lebens, Query Title: Haus des Lebens
# Resultant first title: Queen of the Jungle, Query Title: Queen of the Jungle
# Resultant first title: Grenouilles, Query Title: Grenouilles
# Resultant first title: B. Monkey, Query Title: B. Monkey
# Resultant first title: Zamallu, Query Title: Zamallu
# Resultant first title: Flight to Hong Kong, Query Title: Flight to Hong Kong
# Resultant first title: Where North Holds Sway, Query Title: North
# Resultant first title: Las locuras de Tin-Tan, Query Title: Las locuras de Tin-Tan
# Resultant first title: There Goes the Neighborhood, Query Title: There Goes the Neighborhood
# Resultant first title: Midnattssolens son, Query Title: Midnattssolens son
# Resultant first title: Dr. Wislizenus, Query Title: Dr. Wislizenus
# Resultant first title: Gunsmoke, Query Title: Gunsmoke
# Resultant first title: Hot and Deadly, Query Title: Hot and Deadly
# Resultant first title: The Five-Year Engagement, Query Title: Rules of Engagement
# Resultant first title: The Bofors Gun, Query Title: The Bofors Gun
# Resultant first title: I Married an Angel, Query Title: I Married an Angel
# Resultant first title: The Sport of the Gods, Query Title: Pink Gods
# Resultant first title: One Cut, One Life, Query Title: One Cut, One Life
# Resultant first title: Killing American Style, Query Title: Killing American Style
# Resultant first title: The Astrologer, Query Title: The Zodiac
# Resultant first title: Singing in the Dark, Query Title: Singing in the Dark
# Resultant first title: A Tiger's Tale, Query Title: A Tiger's Tale
# Resultant first title: The Bargee, Query Title: The Bargee
# Resultant first title: If You Build It, Query Title: Made
# Resultant first title: Something Wild, Query Title: In a Wild Moment
# Resultant first title: Carnosaur 3: Primal Species, Query Title: Carnosaur 3: Primal Species
# Resultant first title: The House, Query Title: House No. 44
# Resultant first title: Miracle in Harlem, Query Title: Miracle in Harlem
# Resultant first title: Thoroughbreds, Query Title: If Footmen Tire You What Will Horses Do?
# Resultant first title: Pilgrim's Progress, Query Title: Pilgrim's Progress
# Resultant first title: Itinerary of a Spoiled Child, Query Title: Itinerary of a Spoiled Child
# Resultant first title: The House of Pleasure, Query Title: The House of Pleasure
# Resultant first title: A Summer in La Goulette, Query Title: A Summer in La Goulette
# Resultant first title: My Bloody Valentine, Query Title: The Mysterious Mr. Valentine
# Resultant first title: Warrior of the Lost World, Query Title: Warrior of the Lost World
# Resultant first title: Accepted, Query Title: College
# Resultant first title: The Price of a Party, Query Title: The Price of a Party
# Resultant first title: Tolkien, Query Title: Tolkien
# Resultant first title: Padosan, Query Title: Pamasahe
# Resultant first title: Say Uncle, Query Title: Say Uncle
# Resultant first title: Rebecca, Query Title: Rebecca
# Resultant first title: Carmen & Bolude, Query Title: Carmen & Bolude
# Resultant first title: Badnaam, Query Title: Badnam
# Resultant first title: Government Girl, Query Title: Government Girl
# Resultant first title: Gully, Query Title: Gully Boy
# Resultant first title: Hoor-E-Arab, Query Title: Hoor-E-Arab
# Resultant first title: Five Children and It, Query Title: Five Children and It
# Resultant first title: Caligula et Messaline, Query Title: Caligula et Messaline
# Resultant first title: The Swindlers, Query Title: Moy syn
# Resultant first title: The 8th Day, Query Title: The 8th Day
# Resultant first title: Sunset Park, Query Title: Sunset Park
# Resultant first title: Youth of Athens, Query Title: Youth of Athens
# Resultant first title: Wolne miasto, Query Title: Campaign in Poland
# Resultant first title: Petite Maman, Query Title: Petite Maman
# Resultant first title: The Man Upstairs, Query Title: The Man Upstairs
# Resultant first title: No Way Out, Query Title: No Way Out
# Resultant first title: California Split, Query Title: California Split
# Resultant first title: Summer Holiday, Query Title: Holiday for Henrietta
# Resultant first title: Spiral Farm, Query Title: Spiral Farm
# Resultant first title: Honeymoon, Query Title: Honeymoon
# Resultant first title: War of the Zombies, Query Title: War of the Zombies
# Resultant first title: Schwarze Erde, Query Title: Der schwarze Husar
# Resultant first title: Near the Trail's End, Query Title: Bordertown Trail
# Resultant first title: Ensign Pulver, Query Title: Ensign Pulver
# Resultant first title: The Mist, Query Title: The Mist
# Resultant first title: Versuchen Sie meine Schwester, Query Title: Versuchen Sie meine Schwester
# Resultant first title: A Woman for All Men, Query Title: For a Woman
# Resultant first title: Way of the Black Dragon, Query Title: Black Dragons
# Resultant first title: Sachaa Jhutha, Query Title: Sachaa Jhutha
# Resultant first title: My Dream Is Yours, Query Title: Radio Dreams
# Resultant first title: All Dogs Go to Heaven 2, Query Title: All Dogs Go to Heaven
# Resultant first title: Dr. Jekyll and Mr. Hyde, Query Title: Dr. Jekyll and Mr. Hyde
# Resultant first title: Tom of Finland, Query Title: Tom of Finland
# Resultant first title: Wo der Wildbach durch das Höschen rauscht - Witwen-Report, Query Title: Wo der Wildbach durch das Höschen rauscht - Witwen-Report
# Resultant first title: Daughter of Don Q, Query Title: Daughter of Don Q
# Resultant first title: The Black Tavern, Query Title: The Black Tavern
# Resultant first title: The Night Walker, Query Title: The Night Walker
# Resultant first title: Inclinación sexual al desnudo, Query Title: Inclinación sexual al desnudo
# Resultant first title: Flight of the Red Balloon, Query Title: Flight of the Red Balloon
# Resultant first title: This Side of the Law, Query Title: This Side of the Law
# Resultant first title: Omeng Satanasia, Query Title: Ombre roventi
# Resultant first title: Village of the Damned, Query Title: Village of the Damned
# Resultant first title: Gerald Cranston's Lady, Query Title: Gerald Cranston's Lady
# Resultant first title: ABCD (Any Body Can Dance), Query Title: ABCD (Any Body Can Dance)
# Resultant first title: An Unsuitable Job for a Woman, Query Title: An Unsuitable Job for a Woman
# Resultant first title: A Sertaneja, Query Title: A Sertaneja
# Resultant first title: The Great Smokey Roadblock, Query Title: Catch My Smoke
# Resultant first title: The Preacher's Wife, Query Title: The Preacher's Wife
# Resultant first title: Dance Macabre, Query Title: Dance Macabre
# Resultant first title: Cast a Dark Shadow, Query Title: Midnight Shadow
# Resultant first title: Skyjacked, Query Title: Skyjacked
# Resultant first title: Invaders from Mars, Query Title: Invaders from Mars
# Resultant first title: Good Riddance, Query Title: Good Riddance
# Resultant first title: Son of the Pink Panther, Query Title: Son of the Pink Panther
# Resultant first title: Gabi ng lagim, Query Title: Gabi ng lagim
# Resultant first title: Mark of the Renegade, Query Title: The Renegade
# Resultant first title: Sixteen Candles, Query Title: Sixteen
# Resultant first title: Secret Ballot, Query Title: Secret Ballot
# Resultant first title: Undercover Brother, Query Title: Undercover Brother
# Resultant first title: Cops n Roberts, Query Title: Cops n Roberts
# Resultant first title: Pals of the Range, Query Title: Pals of the Range
# Resultant first title: Vajra Sky Over Tibet, Query Title: Vajra Sky Over Tibet
# Resultant first title: Boom Bust Boom, Query Title: Boom Bust Boom
# Resultant first title: The Out-Laws, Query Title: Broken Laws
# Resultant first title: The Purple Gang, Query Title: True History of the Kelly Gang
# Resultant first title: The Hunting Party, Query Title: The Hunting Party
# Resultant first title: Cheyenne Autumn, Query Title: Cheyenne Autumn
# Resultant first title: Das alte Lied, Query Title: Das alte Lied
# Resultant first title: Betaab, Query Title: Betaab
# Resultant first title: The Punishment, Query Title: The Punishment
# Resultant first title: Humanist Vampire Seeking Consenting Suicidal Person, Query Title: Humanist Vampire Seeking Consenting Suicidal Person
# Resultant first title: Darkman, Query Title: Darkman
# Resultant first title: Twelfth Night, Query Title: Twelfth Night
# Resultant first title: Pata de palo, Query Title: Pata de palo
# Resultant first title: The Lone Ranger, Query Title: The Lone Ranger Rides Again
# Resultant first title: Apartment 143, Query Title: The Apartment
# Resultant first title: The Magician, Query Title: Travelers and Magicians
# Resultant first title: Weekend Pass, Query Title: Weekend Pass
# Resultant first title: Those Magnificent Men in Their Flying Machines or How I Flew from London to Paris in 25 Hours 11 Minutes, Query Title: Those Magnificent Men in Their Flying Machines or How I Flew from London to Paris in 25 Hours 11 Minutes
# Resultant first title: American Mustang, Query Title: Mustang
# Resultant first title: 24 City, Query Title: China Town
# Resultant first title: Jung Kook: I Am Still, Query Title: Kook's Tour
# Resultant first title: The World of Topo Gigio, Query Title: The World of Topo Gigio
# Resultant first title: For Me and My Gal, Query Title: For Me and My Gal
# Resultant first title: Ludzie Wisly, Query Title: Ludzie Wisly
# Resultant first title: Last Pair Out, Query Title: Last Pair Out
# Resultant first title: Jeannou, Query Title: Maurice
# Resultant first title: Boiler Room, Query Title: Boiler Room
# Resultant first title: Kuudes käsky, Query Title: Kaleidoscope
# Resultant first title: Vanity Street, Query Title: Vanity Street
# Resultant first title: Carmen (la de Triana), Query Title: Carmen (la de Triana)
# Resultant first title: Nakinureta haru no onna yo, Query Title: Nakinureta haru no onna yo
# Resultant first title: The Hot Girl Juliet, Query Title: The Hot Girl Juliet
# Resultant first title: Mamma Mia! Here We Go Again, Query Title: Mamma Mia! Here We Go Again
# Resultant first title: The Spirit of Notre Dame, Query Title: Dames
# Resultant first title: Catherine the Last, Query Title: Catherine the Last
# Resultant first title: Rehnaa Hai Terre Dil Mein, Query Title: Rebus
# Resultant first title: The Sheriff and the Satellite Kid, Query Title: The Sheriff and the Satellite Kid
# Resultant first title: Valley of Fire, Query Title: Valley of Fire
# Resultant first title: Red Rock West, Query Title: Red Rock West
# Resultant first title: Where the Bullets Fly, Query Title: Pellet
# Resultant first title: Brimstone & Glory, Query Title: The Event
# Resultant first title: The Perfect Woman, Query Title: Hail the Woman
# Resultant first title: Charlie Chaplin Carnival, Query Title: Charlie Chaplin Carnival
# Resultant first title: Dragon Ball Z: Fusion Reborn, Query Title: Dragon Ball Z: Fusion Reborn
# Resultant first title: Den of Thieves, Query Title: Thieves
# Resultant first title: The Oscar Nominated Short Films 2018: Live Action, Query Title: The Oscar Nominated Short Films 2018: Live Action
# Resultant first title: King of the Ants, Query Title: King of the Ants
# Resultant first title: The Trespasser, Query Title: Trespass
# Resultant first title: Monna Vanna, Query Title: Eisenstein in Guanajuato
# Resultant first title: Jumanji: The Next Level, Query Title: Jubal
# Resultant first title: The Last Judgment, Query Title: The Last Judgment
# Resultant first title: The 13th Letter, Query Title: The 13th Letter
# Resultant first title: The Age of Innocence, Query Title: The Age of Innocence
# Resultant first title: Saadia, Query Title: Safar
# Resultant first title: La polizia ha le mani legate, Query Title: La polizia ha le mani legate
# Resultant first title: The Flower of the North, Query Title: The Flower of the North
# Resultant first title: The West Side Kid, Query Title: The West Side Kid
# Resultant first title: The Holy Inquisition, Query Title: The Holy Inquisition
# Resultant first title: Rumor of Love, Query Title: Rumor of Love
# Resultant first title: The Principles of Lust, Query Title: A Lustful Mind
# Resultant first title: Dick Tracy Returns, Query Title: Dick Tracy Returns
# Resultant first title: Gomorrah, Query Title: Schizopolis
# Resultant first title: The Aviator, Query Title: The Aviator
# Resultant first title: The Other Side of Sunday, Query Title: The Other Side of Sunday
# Resultant first title: Time Out for Love, Query Title: Out of Time
# Resultant first title: Cool Hand Luke, Query Title: Cool Hand Luke
# Resultant first title: Intent to Kill, Query Title: Intent to Kill
# Resultant first title: The Villainess, Query Title: There Are No Villains
# Resultant first title: Gilda Live, Query Title: Gilda Live
# Resultant first title: The Earthling, Query Title: The Earthling
# Resultant first title: Hitler: Beast of Berlin, Query Title: Hitler: Beast of Berlin
# Resultant first title: Vihar, Query Title: Virasat
# Accuracy of search by name: 63.60%
